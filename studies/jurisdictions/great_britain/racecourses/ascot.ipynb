# %% [markdown]
# # Ascot
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# Evidence is kept separate from inference: a race type or distance heading is not automatically a physical course identity.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Ascot**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Source label: `Ascot`
#
# This notebook records venue identity, location, constituent courses/tracks, characteristics, provenance and unresolved questions.

# %%
import pandas as pd

source_label_mapping = pd.DataFrame([{
    "jurisdiction": "Great Britain",
    "candidate_course_label": "Ascot",
    "racecourse_identity": "Ascot",
}])
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. The address is official Ascot data. Coordinates and elevation are secondary geospatial reference values for spatial linkage, not surveyed course coordinates or an elevation profile.

# %%
location_metadata = pd.DataFrame([{
    "racecourse_identity":"Ascot",
    "address":"Ascot Racecourse, High Street, Ascot, SL5 7JX",
    "locality":"Ascot",
    "county_or_region":"Berkshire",
    "postcode":"SL5 7JX",
    "latitude":51.4143,
    "longitude":-0.67849,
    "elevation_m":80,
    "iana_timezone":"Europe/London",
    "coordinate_status":"secondary_venue_point",
    "elevation_status":"secondary_venue_reference",
}])
location_metadata

# %%
location_provenance = pd.DataFrame([
["address/locality/postcode","Ascot Racecourse, High Street, Ascot, SL5 7JX","Ascot Racecourse","Contact information – Ascot Shop","https://shop.ascot.com/policies/contact-information","Official Ascot contact information supplies the physical racecourse address.","verified_official"],
["county_or_region","Berkshire","Ascot Racecourse","Venue Hire at Ascot, Berkshire","https://www.ascot.com/venue-hire","Official Ascot material identifies the venue as Ascot, Berkshire.","verified_official"],
["latitude/longitude","51.4143, -0.67849","Mapcarta (OpenStreetMap / GeoNames)","Ascot Racecourse Map","https://mapcarta.com/28793838","Secondary venue point; not a surveyed centroid, start point or course-specific coordinate.","secondary_geospatial_reference"],
["elevation_m","80","Mapcarta (GeoNames / OpenStreetMap)","Ascot Racecourse Map","https://mapcarta.com/28793838","Single venue reference elevation; not a course elevation profile.","secondary_geospatial_reference"],
["iana_timezone","Europe/London","IANA Time Zone Database","How to Read the tz Database","https://www.iana.org/time-zones/tz-how-to","Assigned from the verified Great Britain venue location.","derived_from_verified_location"],
], columns=["field","value","source_authority","source_title","source_url","evidence_note","verification_status"])
location_provenance.insert(0,"racecourse_identity","Ascot")
location_provenance.insert(5,"accessed_date","2026-08-10")
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# **Flat:** BHA evidence explicitly distinguishes the **Straight Course** and **Round Course**.
#
# **Jump:** a 1999 BHB release describes the Hurdle Course as one of **two National Hunt tracks at Ascot** and gives an all-steeplechase contingency if it is unusable. The other track therefore exists, but its canonical name is unresolved; `Steeplechase Course (working label)` is provisional.
#
# The 2015 BHA schedule separately lists `STEEPLECHASE`, `HURDLE` and `NHFR`. `NHFR` establishes NH Flat use, **not a fifth physical course**.

# %%
course_inventory = pd.DataFrame([
{"racecourse_identity":"Ascot","course_or_track_name":"Straight Course","identity_status":"source_supported","surface":"Turf","primary_use":"Flat","handedness":"Not applicable"},
{"racecourse_identity":"Ascot","course_or_track_name":"Round Course","identity_status":"source_supported","surface":"Turf","primary_use":"Flat","handedness":"Right-handed"},
{"racecourse_identity":"Ascot","course_or_track_name":"Hurdle Course","identity_status":"source_supported","surface":None,"primary_use":"Hurdle","handedness":None},
{"racecourse_identity":"Ascot","course_or_track_name":"Steeplechase Course (working label)","identity_status":"entity_supported_name_unresolved","surface":None,"primary_use":"Steeplechase / chase","handedness":None},
])
course_inventory

# %% [markdown]
# ## Surface, handedness and racing use
#
# - Straight Course — Turf; Flat; handedness `Not applicable` (Inside Rails derivation from verified straight-course structure).
# - Round Course — Turf; Flat; right-handed.
# - Hurdle Course — Hurdle; surface and handedness unresolved.
# - Steeplechase Course (working label) — chase/steeplechase; surface and handedness unresolved.
# - NH Flat — evidenced use; physical-course assignment unresolved.
#
# Flat turf evidence remains `verified_first_pass`; it is not upgraded beyond what the source establishes.

# %%
jump_distance_evidence = pd.DataFrame([
("STEEPLECHASE","2m abt 1f","2m 192yds"),("STEEPLECHASE","2m abt 3f","2m 2f 175yds"),
("STEEPLECHASE","2m abt 5½f","2m 5f 8yds"),("STEEPLECHASE","abt 3m","2m 7f 180yds"),
("STEEPLECHASE","3m abt 6f","3m 5f 94yds"),("HURDLE","abt 2m","1m 7f 152yds"),
("HURDLE","2m abt 3½f","2m 3f 58yds"),("HURDLE","2m abt 6f","2m 5f 141yds"),
("HURDLE","abt 3m","2m 7f 118yds"),("HURDLE","3m abt 1f","3m 97yds"),
("NHFR","2m abt ½f","1m 7f 152yds"),
], columns=["bha_heading","old_description","actual_distance"])
jump_distance_evidence

# %% [markdown]
# ## Course layout and candidates
#
# Primary evidence supports Flat Straight/Round separation and two National Hunt tracks. A current At The Races guide also names an **Old Mile Course** joining the round course in Swinley Bottom. It is retained as a candidate until authoritative evidence establishes whether it is a governed course, branch/start configuration, or part of the Round Course.

# %%
course_candidates_not_promoted = pd.DataFrame([{
    "candidate_name":"Old Mile Course",
    "candidate_type":"Flat course/configuration",
    "source":"At The Races",
    "source_url":"https://www.attheraces.com/course-guides/Ascot",
    "status":"candidate_requires_authoritative_confirmation",
}])
course_candidates_not_promoted

# %% [markdown]
# ## Historical anchors and source mapping
#
# - **18 January 1999** — BHB identifies the Hurdle Course as one of two National Hunt tracks.
# - **1 June 2015** — BHA Jump-distance measurements take effect with `STEEPLECHASE`, `HURDLE` and `NHFR` entries.
#
# One source label (`Ascot`) maps to one racecourse identity but at least four supported course/track entities. `NHFR` is use evidence; Old Mile remains an unpromoted candidate.

# %% [markdown]
# ## Evidence and provenance
#
# The external publisher remains `source_authority` even when Inside Rails derives the governed value. Derivations are marked in `verification_status` and explained in `evidence_note`.

# %%
BHA="British Horseracing Authority"; BHB="BHB / BHA archive"; AR="Ascot Racecourse"
UF="https://www.britishhorseracing.com/press_releases/ascot-may-11th-and-12th-extra-race-and-divisions-to-safeguard-racing/"
UB="https://www.britishhorseracing.com/press_releases/bhb-announces-additional-contingency-arrangements-to-maximise-racing-prospects-for-ascot-this-friday/"
UJ="https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf"
US="https://www.ascot.com/racedays/summer-mile-family-raceday"
UH="https://www.britishhorseracing.com/press_releases/new-range-of-flat-race-starting-procedures-to-be-trialled/"
TF="ASCOT, MAY 11TH AND 12TH: EXTRA RACE AND DIVISIONS TO SAFEGUARD RACING"
TB="BHB ANNOUNCES ADDITIONAL CONTINGENCY ARRANGEMENTS TO MAXIMISE RACING PROSPECTS FOR ASCOT THIS FRIDAY"
TJ="Changes to Jump race distances from 1 June 2015"

def p(course,char,value,authority,title,url,note,status="verified",valid_from=None):
    return ["Great Britain","Ascot",course,char,value,valid_from,None,authority,title,url,"2026-08-10",note,status]

course_characteristic_provenance=pd.DataFrame([
p("Straight Course","course_identity","Straight Course",BHA,TF,UF,"BHA distinguishes straight and round courses operationally."),
p("Round Course","course_identity","Round Course",BHA,TF,UF,"BHA distinguishes round and straight courses operationally."),
p("Hurdle Course","course_identity","Hurdle Course",BHB,TB,UB,"Official release names Hurdle Course and says it is one of two National Hunt tracks."),
p("Steeplechase Course (working label)","course_identity","separate steeplechase/chase track; canonical name unresolved",BHB,TB,UB,"Two NH tracks plus all-steeplechase contingency support a separate non-hurdle track.","verified_entity_name_unresolved"),
p("Hurdle Course","study_period_presence","HURDLE distance set",BHA,TJ,UJ,"BHA 2015 survey lists HURDLE distances for Ascot.","verified","2015-06-01"),
p("Steeplechase Course (working label)","study_period_presence","STEEPLECHASE distance set",BHA,TJ,UJ,"BHA 2015 survey lists STEEPLECHASE distances for Ascot.","verified_entity_name_unresolved","2015-06-01"),
p("Straight Course","surface","Turf",AR,"Racing To Zero Summer Mile Family Raceday",US,"Official Ascot material supplies first-pass grass/turf evidence.","verified_first_pass"),
p("Round Course","surface","Turf",AR,"Racing To Zero Summer Mile Family Raceday",US,"Official Ascot material supplies first-pass grass/turf evidence.","verified_first_pass"),
p("Straight Course","handedness","Not applicable",BHA,TF,UF,"BHA establishes a Straight Course; Inside Rails derives Not applicable because a wholly straight route has no left/right turn.","derived_from_verified_structure"),
p("Round Course","handedness","Right-handed",BHA,"NEW RANGE OF FLAT RACE STARTING PROCEDURES TO BE TRIALLED",UH,"BHA says Ascot is right-handed due to the major bend when racing around a turn."),
p("Straight Course","primary_use","Flat",BHA,TF,UF,"BHA schedules Flat races on straight course."),
p("Round Course","primary_use","Flat",BHA,TF,UF,"BHA schedules Flat races on round course."),
p("Hurdle Course","primary_use","Hurdle",BHB,TB,UB,"Official release distinguishes the Hurdle Course."),
p("Steeplechase Course (working label)","primary_use","Steeplechase / chase",BHB,TB,UB,"All-steeplechase contingency supports steeplechase use on the other NH track.","verified_entity_name_unresolved"),
p(None,"racing_use","NH Flat",BHA,TJ,UJ,"BHA schedule contains NHFR; physical-course assignment unresolved.","verified_use_course_unresolved","2015-06-01"),
],columns=["jurisdiction","racecourse_identity","course_or_track_name","characteristic","value","valid_from","valid_to","source_authority","source_title","source_url","accessed_date","evidence_note","verification_status"])
course_characteristic_provenance

# %% [markdown]
# ## Unresolved questions
#
# 1. Canonical name of the steeplechase/chase track.
# 2. Status of the Old Mile Course.
# 3. Physical-course assignment of NH Flat races.
# 4. Jump-course surface and handedness.
# 5. Redevelopment/physical continuity through the study period.
# 6. Exact geometry, shared sections and start configurations.
# 7. Whether the secondary venue coordinate should be replaced by a defined surveyed reference point.
# 8. Whether elevation should become course-specific profiles.

# %% [markdown]
# ## First-pass conclusion
#
# Ascot is one racecourse identity with at least four supported constituent course/track entities: Straight Course, Round Course, Hurdle Course and a separate steeplechase/chase track whose canonical name remains unresolved.
#
# **Race type, distance heading, course name and physical track are related but not interchangeable.**

# %%
required={"jurisdiction","racecourse_identity","course_or_track_name","characteristic","value","valid_from","valid_to","source_authority","source_title","source_url","accessed_date","evidence_note","verification_status"}
assert len(course_inventory)==4 and course_inventory["course_or_track_name"].is_unique
assert set(jump_distance_evidence["bha_heading"])=={"STEEPLECHASE","HURDLE","NHFR"} and len(jump_distance_evidence)==11
assert "Old Mile Course" not in set(course_inventory["course_or_track_name"])
assert required.issubset(course_characteristic_provenance.columns)
assert course_characteristic_provenance["source_url"].str.startswith("http").all()
assert "NHFR" not in set(course_inventory["course_or_track_name"]) and "NH Flat" in set(course_characteristic_provenance["value"])
assert location_metadata["iana_timezone"].tolist()==["Europe/London"]
assert location_provenance["source_url"].str.startswith("http").all()
assert course_characteristic_provenance.loc[(course_characteristic_provenance["course_or_track_name"]=="Straight Course")&(course_characteristic_provenance["characteristic"]=="handedness"),"source_authority"].iloc[0]==BHA
print("Ascot venue, location and provenance checks passed.")
