# %% [markdown]
# # Newcastle
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Newcastle**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Newcastle`, `Newcastle (AW)`
# - Research-dossier venue label: `Newcastle Racecourse`
# - Physical-model confidence: **medium — taxonomy/detail unresolved**
# - Key temporal boundary: Former Flat Turf Track: 2015-01-01 → winter 2015/16 — exact physical end unresolved; All-Weather Tapeta Track: 2016-05-17 (first Study03 AW observation) → 2026-05-27

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Newcastle`
#
# Newcastle Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Former Flat Turf Track; Turf Jumps Course; All-Weather Tapeta Track. Major 2015–16 physical boundary: Flat turf converted to Tapeta while Jump racing remained on turf. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Newcastle', 'Newcastle'], ['Great Britain', 'Newcastle (AW)', 'Newcastle']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Newcastle',
  'Newcastle Racecourse, Gosforth Park, Newcastle upon Tyne, NE3 5HP',
  'Gosforth Park / Newcastle upon Tyne',
  'Tyne and Wear',
  'NE3 5HP',
  55.0308,
  -1.6117,
  55,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Newcastle',
  'racecourse_identity',
  'Newcastle Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Newcastle',
  'study03_source_labels',
  'Newcastle; Newcastle (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Newcastle',
  'aliases',
  'Newcastle; Gosforth Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Newcastle',
  'physical_venue_address',
  'Newcastle Racecourse, Gosforth Park, Newcastle upon Tyne, NE3 5HP',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Newcastle',
  'locality',
  'Gosforth Park / Newcastle upon Tyne',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Newcastle',
  'county_or_region',
  'Tyne and Wear',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Newcastle',
  'postcode',
  'NE3 5HP',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Newcastle',
  'venue_latitude',
  55.0308,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Newcastle',
  'venue_longitude',
  -1.6117,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Newcastle',
  'venue_reference_elevation_m',
  55,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Newcastle',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Former Flat Turf Track; Turf Jumps Course; All-Weather Tapeta Track**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Newcastle',
  'Former Flat Turf Track',
  'verified_official',
  'course/track',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'turf',
  'Flat',
  'left-handed'],
 ['Newcastle',
  'Turf Jumps Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; chase; NH Flat',
  'left-handed'],
 ['Newcastle',
  'All-Weather Tapeta Track',
  'derived_from_verified_structure',
  'course/track',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'Tapeta',
  'Flat; AW',
  'left-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Former Flat Turf Track** — turf
# - **Turf Jumps Course** — turf
# - **All-Weather Tapeta Track** — Tapeta

# %% [markdown]
# ## Handedness
#
# - **Former Flat Turf Track** — left-handed
# - **Turf Jumps Course** — left-handed
# - **All-Weather Tapeta Track** — left-handed

# %% [markdown]
# ## Racing use
#
# - **Former Flat Turf Track** — Flat
# - **Turf Jumps Course** — hurdle; chase; NH Flat
# - **All-Weather Tapeta Track** — Flat; AW

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Newcastle',
  'Former Flat Turf Track',
  'former Flat turf track',
  'converted to all-weather while the Jumps turf course was retained',
  None,
  None,
  None,
  None,
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant.',
  'verified_official'],
 ['Newcastle',
  'Turf Jumps Course',
  'galloping National Hunt turf course',
  'retained through the Flat-track conversion',
  None,
  None,
  'uphill toward home turn',
  None,
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  None,
  'verified_official'],
 ['Newcastle',
  'All-Weather Tapeta Track',
  'oval plus floodlit straight mile',
  'replacement for the former Flat turf track',
  None,
  'straight mile',
  None,
  None,
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date.',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [['Newcastle',
  'winter 2015/16; AW racing observed from 2016',
  'surface / reconstruction',
  'former Flat turf track',
  'Flat turf',
  'Tapeta all-weather track with floodlit straight mile; Jump programme retained on turf',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'verified_official',
  'Major physical-model boundary; exact construction handover date remains unresolved.']],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Newcastle`, `Newcastle (AW)` → **Newcastle** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0364',
  'Great Britain',
  'Newcastle',
  None,
  'racecourse_identity',
  'Newcastle Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0365',
  'Great Britain',
  'Newcastle',
  None,
  'study03_source_labels',
  'Newcastle; Newcastle (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0366',
  'Great Britain',
  'Newcastle',
  None,
  'aliases',
  'Newcastle; Gosforth Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0367',
  'Great Britain',
  'Newcastle',
  None,
  'physical_venue_address',
  'Newcastle Racecourse, Gosforth Park, Newcastle upon Tyne, NE3 5HP',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0368',
  'Great Britain',
  'Newcastle',
  None,
  'locality',
  'Gosforth Park / Newcastle upon Tyne',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0369',
  'Great Britain',
  'Newcastle',
  None,
  'county_or_region',
  'Tyne and Wear',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0370',
  'Great Britain',
  'Newcastle',
  None,
  'postcode',
  'NE3 5HP',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0371',
  'Great Britain',
  'Newcastle',
  None,
  'venue_latitude',
  55.0308,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0372',
  'Great Britain',
  'Newcastle',
  None,
  'venue_longitude',
  -1.6117,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0373',
  'Great Britain',
  'Newcastle',
  None,
  'venue_reference_elevation_m',
  55,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103310',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0374',
  'Great Britain',
  'Newcastle',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1225',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'course_or_track_name',
  'Former Flat Turf Track',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1226',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'entity_type',
  'course/track',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1227',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'surface',
  'turf',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1228',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'racing_use',
  'Flat',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1229',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'handedness',
  'left-handed',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1230',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'course_geometry',
  'former Flat turf track',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1231',
  'Great Britain',
  'Newcastle',
  'Former Flat Turf Track',
  'physical_relationship',
  'converted to all-weather while the Jumps turf course was retained',
  '2015-01-01',
  'winter 2015/16 — exact physical end unresolved',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The exact physical decommissioning/commissioning date was not found; do not treat the text valid_to as a surveyed instant. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1232',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'course_or_track_name',
  'Turf Jumps Course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1233',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1234',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1235',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'racing_use',
  'hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1236',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1237',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'course_geometry',
  'galloping National Hunt turf course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1238',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'physical_relationship',
  'retained through the Flat-track conversion',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1239',
  'Great Britain',
  'Newcastle',
  'Turf Jumps Course',
  'gradients_or_elevation_characteristics',
  'uphill toward home turn',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1240',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'course_or_track_name',
  'All-Weather Tapeta Track',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1241',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'entity_type',
  'course/track',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1242',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'surface',
  'Tapeta',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1243',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'racing_use',
  'Flat; AW',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1244',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'handedness',
  'left-handed',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1245',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'course_geometry',
  'oval plus floodlit straight mile',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1246',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'physical_relationship',
  'replacement for the former Flat turf track',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure'],
 ['P1247',
  'Great Britain',
  'Newcastle',
  'All-Weather Tapeta Track',
  'straight_length_or_route',
  'straight mile',
  '2016-05-17 (first Study03 AW observation)',
  '2026-05-27',
  'British Horseracing Authority',
  'BHA approves Newcastle all-weather track plans',
  'https://www.britishhorseracing.com/press_releases/bha-approves-newcastle-racecourse-plans-for-all-weather-track/',
  '2026-08-11',
  'The start boundary is the first Study03 AW race observation, not an asserted construction-survey date. Assertion retained at the '
  'narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent '
  'track.',
  'derived_from_verified_structure']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [['Newcastle',
  'What exact date did the former Flat turf track cease to exist physically during the 2015/16 conversion?',
  'Official sources establish approval/conversion and 2016 AW use but not a surveyed demolition/commissioning instant.',
  'BHA conversion material; Study03 first AW observation',
  'medium — temporal boundary',
  'genuine_unresolved',
  'unresolved_after_research']],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Newcastle Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Former Flat Turf Track; Turf Jumps Course; All-Weather Tapeta Track. Major 2015–16 physical boundary: Flat turf converted to Tapeta while Jump racing remained on turf. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Newcastle'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Newcastle' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
