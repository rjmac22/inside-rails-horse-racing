# %% [markdown]
# # Ayr
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# Run all cells to render the governed venue, course/track, provenance, historical-change and unresolved-question record.

# %%
from pathlib import Path
p = Path.cwd()
while not (p / 'studies').exists() and p != p.parent:
    p = p.parent
exec((p / 'studies/jurisdictions/great_britain/racecourses/_racecourse_notebook_support.py').read_text())
tables = render_venue('ayr')
