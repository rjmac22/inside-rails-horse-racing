# %% [markdown]
# # Haydock Park
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Haydock Park**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Haydock`
# - Research-dossier venue label: `Haydock Park Racecourse`
# - Physical-model confidence: **medium — taxonomy/detail unresolved**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Haydock Park`
#
# Haydock Park Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Flat Course; Lancashire Chase Course; Inner Chase Course. Flat course plus separately named Lancashire and Inner chase courses; hurdle alignment is not separately promoted. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Haydock', 'Haydock Park']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Haydock Park',
  'Haydock Park Racecourse, Haydock, Merseyside, WA12 0HQ',
  'Haydock / Newton-le-Willows',
  'Merseyside',
  'WA12 0HQ',
  53.47818,
  -2.62174,
  45,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Haydock Park',
  'racecourse_identity',
  'Haydock Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Haydock Park',
  'study03_source_labels',
  'Haydock',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Haydock Park',
  'aliases',
  'Haydock; Haydock Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Haydock Park',
  'physical_venue_address',
  'Haydock Park Racecourse, Haydock, Merseyside, WA12 0HQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Haydock Park',
  'locality',
  'Haydock / Newton-le-Willows',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Haydock Park',
  'county_or_region',
  'Merseyside',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Haydock Park',
  'postcode',
  'WA12 0HQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Haydock Park',
  'venue_latitude',
  53.47818,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Haydock Park',
  'venue_longitude',
  -2.62174,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Haydock Park',
  'venue_reference_elevation_m',
  45,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Haydock Park',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Flat Course; Lancashire Chase Course; Inner Chase Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Haydock Park', 'Flat Course', 'verified_official', 'course/track', '2015-01-01', '2026-05-27', 'turf', 'Flat', 'left-handed'],
 ['Haydock Park',
  'Lancashire Chase Course',
  'derived_from_verified_structure',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'chase',
  'left-handed'],
 ['Haydock Park',
  'Inner Chase Course',
  'derived_from_verified_structure',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'chase',
  'left-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Flat Course** — turf
# - **Lancashire Chase Course** — turf
# - **Inner Chase Course** — turf

# %% [markdown]
# ## Handedness
#
# - **Flat Course** — left-handed
# - **Lancashire Chase Course** — left-handed
# - **Inner Chase Course** — left-handed

# %% [markdown]
# ## Racing use
#
# - **Flat Course** — Flat
# - **Lancashire Chase Course** — chase
# - **Inner Chase Course** — chase

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Haydock Park',
  'Flat Course',
  'left-handed Flat course',
  'distinct Flat course at Haydock Park',
  None,
  'home straight about 4.5f',
  'slight uphill in home straight',
  None,
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  None,
  'verified_official'],
 ['Haydock Park',
  'Lancashire Chase Course',
  'separately named chase course',
  'one of two chase courses named by BHA/technical material',
  None,
  None,
  None,
  'drop fences',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  None,
  'derived_from_verified_structure'],
 ['Haydock Park',
  'Inner Chase Course',
  'inner chase course',
  'one of two chase courses named by BHA/technical material',
  None,
  None,
  None,
  'drop fences',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  None,
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [['Haydock Park',
  '2026-05-23',
  'ground failure / emergency route change',
  'Flat course',
  'outer Flat track in normal use',
  'hole/fissure prompted an inside-line switch and abandonment of round-course racing',
  'The Jockey Club',
  'Haydock Park track update',
  'https://www.thejockeyclub.co.uk/haydock/media/news/2026/05/haydock-park-track-update/',
  '2026-08-11',
  'verified_official',
  'Event within scope; emergency routing is not promoted as a new permanent track.']],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Haydock` → **Haydock Park** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0232',
  'Great Britain',
  'Haydock Park',
  None,
  'racecourse_identity',
  'Haydock Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0233',
  'Great Britain',
  'Haydock Park',
  None,
  'study03_source_labels',
  'Haydock',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0234',
  'Great Britain',
  'Haydock Park',
  None,
  'aliases',
  'Haydock; Haydock Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0235',
  'Great Britain',
  'Haydock Park',
  None,
  'physical_venue_address',
  'Haydock Park Racecourse, Haydock, Merseyside, WA12 0HQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0236',
  'Great Britain',
  'Haydock Park',
  None,
  'locality',
  'Haydock / Newton-le-Willows',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0237',
  'Great Britain',
  'Haydock Park',
  None,
  'county_or_region',
  'Merseyside',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0238',
  'Great Britain',
  'Haydock Park',
  None,
  'postcode',
  'WA12 0HQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0239',
  'Great Britain',
  'Haydock Park',
  None,
  'venue_latitude',
  53.47818,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0240',
  'Great Britain',
  'Haydock Park',
  None,
  'venue_longitude',
  -2.62174,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0241',
  'Great Britain',
  'Haydock Park',
  None,
  'venue_reference_elevation_m',
  45,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102976',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0242',
  'Great Britain',
  'Haydock Park',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1130',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'course_or_track_name',
  'Flat Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1131',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1132',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1133',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'racing_use',
  'Flat',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1134',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1135',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'course_geometry',
  'left-handed Flat course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1136',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'physical_relationship',
  'distinct Flat course at Haydock Park',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1137',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'straight_length_or_route',
  'home straight about 4.5f',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1138',
  'Great Britain',
  'Haydock Park',
  'Flat Course',
  'gradients_or_elevation_characteristics',
  'slight uphill in home straight',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Haydock Park Racecourse Map',
  'https://www.thejockeyclub.co.uk/haydock/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1139',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'course_or_track_name',
  'Lancashire Chase Course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1140',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1141',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1142',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'racing_use',
  'chase',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1143',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1144',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'course_geometry',
  'separately named chase course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1145',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'physical_relationship',
  'one of two chase courses named by BHA/technical material',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1146',
  'Great Britain',
  'Haydock Park',
  'Lancashire Chase Course',
  'permanent_obstacles_or_distinctive_features',
  'drop fences',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1147',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'course_or_track_name',
  'Inner Chase Course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1148',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1149',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1150',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'racing_use',
  'chase',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1151',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1152',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'course_geometry',
  'inner chase course',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1153',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'physical_relationship',
  'one of two chase courses named by BHA/technical material',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P1154',
  'Great Britain',
  'Haydock Park',
  'Inner Chase Course',
  'permanent_obstacles_or_distinctive_features',
  'drop fences',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'derived_from_verified_structure']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Haydock Park',
  'HURDLE',
  'BHA heading / current official layout',
  'discipline/obstacle alignment',
  "Current official material describes hurdles set inside the chase course; 'HURDLE' alone does not justify another permanent course row.",
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'derived_from_verified_structure'],
 ['Haydock Park',
  'BRUSH HURDLE STARTS',
  'BHA distance heading',
  'start grouping',
  'A start grouping is not a separately governed physical course.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Haydock Park',
  "BHA names Inner and Lancashire chase courses; current official material also uses 'inside' descriptively for hurdle positioning and "
  'emergency Flat routing.',
  'BHA / Jockey Club terminology',
  "'Inner' can describe different physical contexts.",
  "Keep the separately named chase courses; do not create an 'inner Flat course' from emergency routing.",
  'high']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [['Haydock Park',
  'What are the exact physical boundaries and modern validity of Lancashire Chase Course versus Inner Chase Course?',
  'The names are supported, but a precise current engineering/GIS description was not located.',
  'BHA measurement material; current Jockey Club layout material; technical course guide',
  'medium — physical hierarchy',
  'genuine_unresolved',
  'unresolved_after_research']],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Haydock Park Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Flat Course; Lancashire Chase Course; Inner Chase Course. Flat course plus separately named Lancashire and Inner chase courses; hurdle alignment is not separately promoted. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Haydock Park'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Haydock Park' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
