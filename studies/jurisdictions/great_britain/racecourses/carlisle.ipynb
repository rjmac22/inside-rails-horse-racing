# %% [markdown]
# # Carlisle
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Carlisle**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Carlisle`
# - Research-dossier venue label: `Carlisle Racecourse`
# - Physical-model confidence: **high for the four promoted course identities; historical OLD/NEW hurdle-label mapping remains unresolved**
# - Key temporal boundary: no in-scope identity creation/removal boundary established; the Inner Hurdle Course predates the study period.

# %%
import pandas as pd

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Carlisle`
#
# The evidence supports four stable constituent physical racing-course identities during the Study 03 period:
#
# - **Flat Course**
# - **Chase Course**
# - **Inner Hurdle Course**
# - **Outer Hurdle Course**
#
# The Jockey Club explicitly describes the Flat course separately from the chase and jumps tracks. The BHA explicitly refers to Carlisle's Chase Course and Inner Hurdle Course. Supporting technical evidence describes two separate hurdle tracks, an inner and an outer track.
#
# Historical BHA `OLD HURDLE` and `NEW HURDLE` labels remain evidence of distinct hurdle alignments, but their exact mapping to modern inner/outer terminology is not asserted without direct evidence.

# %% [markdown]
# ## Source-data labels
#
# The source label maps to the governed racecourse identity below. It is not treated as a physical course identifier.

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Carlisle', 'Carlisle']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited source and are not represented as surveyed course-centre coordinates or an elevation profile.

# %%
location_metadata = pd.DataFrame(
    [[
        'Carlisle',
        'Carlisle Racecourse, Carlisle, Cumbria, CA2 4TS',
        'Carlisle',
        'Cumbria',
        'CA2 4TS',
        54.8622,
        -2.93358,
        52,
        'Europe/London',
        'secondary_geospatial_reference',
        'single venue reference elevation; NOT course profile',
    ]],
    columns=[
        'racecourse_identity', 'address', 'locality', 'county_or_region',
        'postcode', 'latitude', 'longitude', 'elevation_m', 'iana_timezone',
        'coordinate_status', 'elevation_status',
    ],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [
        ['Carlisle', 'racecourse_identity', 'Carlisle Racecourse', '2015-01-01', '2026-05-27',
         'British Horseracing Authority', 'Heritage — British racecourses',
         'https://www.britishhorseracing.com/heritage/', '2026-08-11',
         'Stable venue identity.', 'verified_official'],
        ['Carlisle', 'study03_source_labels', 'Carlisle', '2015-01-01', '2026-05-27',
         'Inside Rails', 'Study 03 — What is a British racecourse?',
         'https://github.com/rjmac22/inside-rails-horse-racing/blob/study/gb-03-racecourses/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
         '2026-08-11',
         'Source label retained as a source classification rather than promoted to a physical course identity.',
         'verified'],
        ['Carlisle', 'physical_venue_address', 'Carlisle Racecourse, Carlisle, Cumbria, CA2 4TS',
         '2015-01-01', '2026-05-27', 'British Horseracing Authority', 'Heritage — British racecourses',
         'https://www.britishhorseracing.com/heritage/', '2026-08-11',
         'Best-supported venue address/locality/postcode formulation.', 'derived_from_verified_location'],
        ['Carlisle', 'locality', 'Carlisle', '2015-01-01', '2026-05-27',
         'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata', 'Racecourse map',
         'https://mapcarta.com/29102968', '2026-08-11',
         'Secondary spatial reference used to localise the venue.', 'secondary_geospatial_reference'],
        ['Carlisle', 'county_or_region', 'Cumbria', '2015-01-01', '2026-05-27',
         'British Horseracing Authority', 'Heritage — British racecourses',
         'https://www.britishhorseracing.com/heritage/', '2026-08-11',
         'County/region retained at the venue level.', 'verified_official'],
        ['Carlisle', 'postcode', 'CA2 4TS', '2015-01-01', '2026-05-27',
         'British Horseracing Authority', 'Heritage — British racecourses',
         'https://www.britishhorseracing.com/heritage/', '2026-08-11',
         'Current best-supported postcode.', 'derived_from_verified_location'],
        ['Carlisle', 'venue_latitude', 54.8622, '2015-01-01', '2026-05-27',
         'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata', 'Racecourse map',
         'https://mapcarta.com/29102968', '2026-08-11',
         'Secondary geospatial venue reference point; not a course centroid.', 'secondary_geospatial_reference'],
        ['Carlisle', 'venue_longitude', -2.93358, '2015-01-01', '2026-05-27',
         'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata', 'Racecourse map',
         'https://mapcarta.com/29102968', '2026-08-11',
         'Secondary geospatial venue reference point; not a course centroid.', 'secondary_geospatial_reference'],
        ['Carlisle', 'venue_reference_elevation_m', 52, '2015-01-01', '2026-05-27',
         'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata', 'Racecourse map',
         'https://mapcarta.com/29102968', '2026-08-11',
         'Single venue reference elevation; not a course elevation profile.', 'secondary_geospatial_reference'],
        ['Carlisle', 'iana_timezone', 'Europe/London', '2015-01-01', '2026-05-27',
         'IANA Time Zone Database', 'zone1970.tab',
         'https://data.iana.org/time-zones/tzdb/zone1970.tab', '2026-08-11',
         'Derived from the verified Great Britain venue location.', 'derived_from_verified_location'],
    ],
    columns=[
        'racecourse_identity', 'field', 'value', 'valid_from', 'valid_to',
        'source_authority', 'source_title', 'source_url', 'accessed_date',
        'evidence_note', 'verification_status',
    ],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed Study 03 inventory:
#
# - **Flat Course**
# - **Chase Course**
# - **Inner Hurdle Course**
# - **Outer Hurdle Course**
#
# These are promoted as stable physical course identities. The historical `OLD HURDLE` / `NEW HURDLE` names are not used as additional identities because the remaining uncertainty is their mapping onto the modern hurdle-course terminology.

# %%
# Stable course identities are separated from racing-use labels and from
# the unresolved historical OLD/NEW hurdle-name mapping.
course_inventory = pd.DataFrame(
    [
        ['Carlisle', 'Flat Course', 'verified_official', 'course/track',
         '2015-01-01', '2026-05-27', 'turf', 'Flat', 'right-handed'],
        ['Carlisle', 'Chase Course', 'verified_official', 'course/track',
         '2015-01-01', '2026-05-27', 'turf', 'chase', 'right-handed'],
        ['Carlisle', 'Inner Hurdle Course', 'verified_official', 'course/track',
         '2015-01-01', '2026-05-27', 'turf', 'hurdle; NH Flat', 'right-handed'],
        ['Carlisle', 'Outer Hurdle Course', 'supported_secondary_technical', 'course/track',
         '2015-01-01', '2026-05-27', 'turf', 'hurdle', 'right-handed'],
    ],
    columns=[
        'racecourse_identity', 'course_or_track_name', 'identity_status',
        'entity_type', 'valid_from', 'valid_to', 'surface', 'primary_use',
        'handedness',
    ],
)
course_inventory

# %% [markdown]
# ## Surface
#
# All four promoted course identities are turf.

# %% [markdown]
# ## Handedness
#
# The Carlisle racing layout is right-handed; this characteristic is retained for all four promoted course identities.

# %% [markdown]
# ## Racing use
#
# - **Flat Course** — Flat racing
# - **Chase Course** — steeplechase
# - **Inner Hurdle Course** — hurdle racing; NH Flat use may use the hurdle racing line
# - **Outer Hurdle Course** — hurdle racing
#
# Racing use is retained as a characteristic, not used by itself to create an identity.

# %% [markdown]
# ## Course layout and physical characteristics
#
# The key Study 03 physical finding is multiplicity: Carlisle is not adequately represented by a single generic turf-course row. Public evidence supports a Flat course, a Chase Course and two hurdle tracks.

# %%
course_physical_characteristics = pd.DataFrame(
    [
        ['Carlisle', 'Flat Course', 'part of the right-handed Carlisle turf layout',
         'separately referred to as the Flat course by Carlisle ground staff', None, None,
         'notably uphill finish', None, 'The Jockey Club',
         "Racecourse Beats The Heatwave To Cut A Dash Ahead Of Ladies Night",
         'https://www.thejockeyclub.co.uk/carlisle/media/news/2018/07/ladies-night/',
         '2026-08-11',
         'Carlisle head groundsman distinguishes the Flat course from the chase and jumps tracks.',
         'verified_official'],
        ['Carlisle', 'Chase Course', 'part of the right-handed Carlisle turf layout',
         'physically distinct enough for chase racing to be abandoned while hurdle racing continued',
         None, None, 'notably uphill finish', 'steeplechase fences',
         'British Horseracing Authority',
         'BHA confirms all-Hurdle card at Carlisle on Sunday 14 December',
         'https://www.britishhorseracing.com/press_releases/bha-confirms-all-hurdle-card-at-carlisle-on-sunday-14-december/',
         '2026-08-11',
         'BHA explicitly refers to areas of false ground on the Chase course.',
         'verified_official'],
        ['Carlisle', 'Inner Hurdle Course', 'inner hurdle track',
         'one of two hurdle tracks', None, None, 'notably uphill finish', 'hurdles',
         'British Horseracing Authority',
         'BHA confirms all-Hurdle card at Carlisle on Sunday 14 December',
         'https://www.britishhorseracing.com/press_releases/bha-confirms-all-hurdle-card-at-carlisle-on-sunday-14-december/',
         '2026-08-11',
         'Carlisle Clerk of the Course explicitly refers to the Inner Hurdle course.',
         'verified_official'],
        ['Carlisle', 'Outer Hurdle Course', 'outer hurdle track',
         'one of two hurdle tracks', None, None, 'notably uphill finish', 'hurdles',
         'BettingSites.co', 'Carlisle Racecourse Guide',
         'https://www.bettingsites.co/sports/horse-racing/racecourses/carlisle/',
         '2026-08-11',
         'Secondary technical description identifies separate inner and outer hurdle tracks; used because equivalent current primary naming for the outer track was not found.',
         'supported_secondary_technical'],
    ],
    columns=[
        'racecourse_identity', 'course_or_track_name', 'course_geometry',
        'physical_relationship', 'circumference_or_length',
        'straight_length_or_route', 'gradients_or_elevation_characteristics',
        'permanent_obstacles_or_distinctive_features', 'source_authority',
        'source_title', 'exact_source_url', 'accessed_date', 'evidence_note',
        'verification_status',
    ],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# The Inner Hurdle Course predates the Study 03 period. No in-scope creation/removal boundary for the four promoted identities is asserted in this notebook.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=[
        'racecourse_identity', 'change_date_or_period', 'change_type',
        'affected_course_or_track', 'before_state', 'after_state',
        'source_authority', 'source_title', 'source_url', 'accessed_date',
        'verification_status', 'model_impact',
    ],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Carlisle` → **Carlisle racecourse** → **Flat Course / Chase Course / Inner Hurdle Course / Outer Hurdle Course**
#
# This preserves the Study 03 rule:
#
# `source label != racecourse != course/track`

# %% [markdown]
# ## Evidence and provenance
#
# Each promoted course identity has assertion-level provenance. Primary official evidence is preferred; the Outer Hurdle Course retains an explicit secondary-technical status because equivalent current primary naming was not found.

# %%
course_characteristic_provenance = pd.DataFrame(
    [
        ['P0067', 'Great Britain', 'Carlisle', None, 'racecourse_identity',
         'Carlisle Racecourse', '2015-01-01', '2026-05-27',
         'British Horseracing Authority', 'Heritage — British racecourses',
         'https://www.britishhorseracing.com/heritage/', '2026-08-11',
         'Stable venue identity.', 'verified_official'],
        ['P0068', 'Great Britain', 'Carlisle', None, 'study03_source_labels',
         'Carlisle', '2015-01-01', '2026-05-27',
         'Inside Rails', 'Study 03 — What is a British racecourse?',
         'https://github.com/rjmac22/inside-rails-horse-racing/blob/study/gb-03-racecourses/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
         '2026-08-11',
         'Source label retained as source classification rather than physical identity.',
         'verified'],
        ['P1067', 'Great Britain', 'Carlisle', 'Flat Course', 'course_or_track_name',
         'Flat Course', '2015-01-01', '2026-05-27',
         'The Jockey Club',
         'Racecourse Beats The Heatwave To Cut A Dash Ahead Of Ladies Night',
         'https://www.thejockeyclub.co.uk/carlisle/media/news/2018/07/ladies-night/',
         '2026-08-11',
         'Carlisle head groundsman separately refers to the Flat course and to chase and jumps tracks.',
         'verified_official'],
        ['P1068', 'Great Britain', 'Carlisle', 'Chase Course', 'course_or_track_name',
         'Chase Course', '2015-01-01', '2026-05-27',
         'British Horseracing Authority',
         'BHA confirms all-Hurdle card at Carlisle on Sunday 14 December',
         'https://www.britishhorseracing.com/press_releases/bha-confirms-all-hurdle-card-at-carlisle-on-sunday-14-december/',
         '2026-08-11',
         'BHA explicitly names the Chase course when explaining why chase races were abandoned.',
         'verified_official'],
        ['P1069', 'Great Britain', 'Carlisle', 'Inner Hurdle Course', 'course_or_track_name',
         'Inner Hurdle Course', '2015-01-01', '2026-05-27',
         'British Horseracing Authority',
         'BHA confirms all-Hurdle card at Carlisle on Sunday 14 December',
         'https://www.britishhorseracing.com/press_releases/bha-confirms-all-hurdle-card-at-carlisle-on-sunday-14-december/',
         '2026-08-11',
         'Carlisle Clerk of the Course explicitly names the Inner Hurdle course.',
         'verified_official'],
        ['P1070', 'Great Britain', 'Carlisle', 'Outer Hurdle Course', 'course_or_track_name',
         'Outer Hurdle Course', '2015-01-01', '2026-05-27',
         'BettingSites.co', 'Carlisle Racecourse Guide',
         'https://www.bettingsites.co/sports/horse-racing/racecourses/carlisle/',
         '2026-08-11',
         'Secondary technical source describes two separate hurdle tracks, inner and outer; retained with explicit secondary status.',
         'supported_secondary_technical'],
        ['P1071', 'Great Britain', 'Carlisle', None, 'historical_hurdle_labels',
         'OLD HURDLE / NEW HURDLE', '2015-01-01', '2015-12-31',
         'British Horseracing Authority', '2015 race-distance measurement material',
         'https://www.britishhorseracing.com/', '2026-08-11',
         'Historical OLD/NEW headings support distinct hurdle alignments, but exact mapping to modern inner/outer names remains unresolved.',
         'verified_official_but_mapping_unresolved'],
    ],
    columns=[
        'assertion_id', 'jurisdiction', 'racecourse_identity',
        'course_or_track_name', 'characteristic', 'value', 'valid_from',
        'valid_to', 'source_authority', 'source_title', 'source_url',
        'accessed_date', 'evidence_note', 'verification_status',
    ],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# The historical `OLD HURDLE` and `NEW HURDLE` labels are not promoted as additional identities. The course multiplicity is already represented by the modern hurdle-course identities; only the exact historical-name mapping remains unresolved.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [
        ['Carlisle', 'OLD HURDLE / NEW HURDLE', 'BHA 2015 distance headings',
         'historical hurdle-course labels',
         'Evidence supports two hurdle courses, but the exact OLD/NEW to inner/outer name mapping is not directly established.',
         'retain as historical terminology; do not create extra identities',
         'British Horseracing Authority', '2015 race-distance measurement material',
         'https://www.britishhorseracing.com/', '2026-08-11',
         'verified_official_but_mapping_unresolved'],
    ],
    columns=[
        'racecourse_identity', 'candidate_label', 'evidence_source',
        'candidate_type', 'why_not_promoted', 'handling',
        'source_authority', 'source_title', 'source_url',
        'accessed_date', 'verification_status',
    ],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human review

# %%
human_review_items = pd.DataFrame(
    [
        ['Carlisle',
         'Exact mapping of historical BHA OLD HURDLE and NEW HURDLE labels to modern Inner Hurdle Course and Outer Hurdle Course terminology is unresolved.',
         'BHA historical terminology versus modern terminology',
         'This no longer affects the governed physical course count, but matters for historical label reconciliation.',
         'Keep the four promoted modern identities; do not assert an OLD/NEW mapping without direct evidence.',
         'low'],
    ],
    columns=[
        'racecourse_identity', 'anomaly', 'conflicting_sources_or_terms',
        'why_human_review', 'conservative_handling', 'priority',
    ],
)
human_review_items

# %% [markdown]
# ## Unresolved questions

# %%
unresolved_questions = pd.DataFrame(
    [
        ['Carlisle',
         'How do the 2015 BHA labels OLD HURDLE and NEW HURDLE map onto the modern Inner Hurdle Course and Outer Hurdle Course terminology?',
         'The physical existence of two hurdle courses is supported, but the exact historical-name mapping has not been directly established.',
         'BHA 2015 distance material; BHA 2025 Inner Hurdle Course statement; Jockey Club course-maintenance description; secondary technical course guide.',
         'low — historical terminology only; no longer affects governed course count',
         'genuine_unresolved',
         'unresolved_after_research'],
    ],
    columns=[
        'racecourse_identity', 'question', 'why_unresolved',
        'research_attempted', 'impact', 'unresolved_class',
        'verification_status',
    ],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Carlisle cannot be represented faithfully by a single generic turf-course identity.
#
# Study 03 evidence supports four stable constituent physical course identities during the study period:
#
# 1. **Flat Course**
# 2. **Chase Course**
# 3. **Inner Hurdle Course**
# 4. **Outer Hurdle Course**
#
# The remaining unresolved issue is limited to the exact mapping of historical `OLD HURDLE` and `NEW HURDLE` terminology onto the modern inner/outer hurdle-course names. It does **not** affect the governed course count.
#
# Carlisle therefore provides strong evidence for the central Study 03 distinction between the racecourse venue and the physical courses/tracks within it.

# %% [markdown]
# ## Validation

# %%
# Closeout checks protect the national consolidation from silently
# receiving an incomplete Carlisle structure.
assert len(source_label_mapping) == 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Carlisle'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) == 4
assert set(course_inventory['course_or_track_name']) == {
    'Flat Course', 'Chase Course', 'Inner Hurdle Course', 'Outer Hurdle Course'
}
assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
assert len(unresolved_questions) == 1
print('Carlisle venue, four-course model and provenance checks passed.')

# %% [markdown]
# ## Sources / provenance completeness
#
# The notebook retains assertion-level source records in `location_provenance` and `course_characteristic_provenance`.
#
# The Carlisle physical-course correction uses:
# - The Jockey Club evidence distinguishing the Flat course from chase and jumps tracks;
# - BHA evidence explicitly naming the Chase Course and Inner Hurdle Course;
# - secondary technical evidence for the outer/inner two-hurdle-track structure, clearly marked as secondary;
# - historical BHA OLD/NEW terminology retained without forcing an unsupported mapping.
#
# No material course-identity claim used in the conclusion is left only in prose.
