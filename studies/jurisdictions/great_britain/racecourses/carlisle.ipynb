# %% [markdown]
# # Carlisle
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Carlisle**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Carlisle`
# - Research-dossier venue label: `Carlisle Racecourse`
# - Physical-model confidence: **medium — taxonomy/detail unresolved**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Carlisle`
#
# Carlisle Racecourse is represented by 1 governed physical course/track/configuration row(s) in this research model: Main Turf Course (conservative descriptive row). BHA 2015 material names Old and New Hurdle headings; they are held out pending authoritative physical confirmation. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Carlisle', 'Carlisle']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Carlisle',
  'Carlisle Racecourse, Carlisle, Cumbria, CA2 4TS',
  'Carlisle',
  'Cumbria',
  'CA2 4TS',
  54.8622,
  -2.93358,
  52,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Carlisle',
  'racecourse_identity',
  'Carlisle Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Carlisle',
  'study03_source_labels',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Carlisle',
  'aliases',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Carlisle',
  'physical_venue_address',
  'Carlisle Racecourse, Carlisle, Cumbria, CA2 4TS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Carlisle',
  'locality',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Carlisle',
  'county_or_region',
  'Cumbria',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Carlisle',
  'postcode',
  'CA2 4TS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Carlisle',
  'venue_latitude',
  54.8622,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Carlisle',
  'venue_longitude',
  -2.93358,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Carlisle',
  'venue_reference_elevation_m',
  52,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Carlisle',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Main Turf Course (conservative descriptive row)**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'derived_from_verified_structure',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'Flat; chase; hurdle; NH Flat',
  'right-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Main Turf Course (conservative descriptive row)** — turf

# %% [markdown]
# ## Handedness
#
# - **Main Turf Course (conservative descriptive row)** — right-handed

# %% [markdown]
# ## Racing use
#
# - **Main Turf Course (conservative descriptive row)** — Flat; chase; hurdle; NH Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'pear-shaped/round Carlisle course',
  'Old/New hurdle labels are held as candidates pending authoritative physical confirmation',
  None,
  None,
  'notably uphill finish',
  None,
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses.',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Carlisle` → **Carlisle** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0067',
  'Great Britain',
  'Carlisle',
  None,
  'racecourse_identity',
  'Carlisle Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0068',
  'Great Britain',
  'Carlisle',
  None,
  'study03_source_labels',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0069',
  'Great Britain',
  'Carlisle',
  None,
  'aliases',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0070',
  'Great Britain',
  'Carlisle',
  None,
  'physical_venue_address',
  'Carlisle Racecourse, Carlisle, Cumbria, CA2 4TS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0071',
  'Great Britain',
  'Carlisle',
  None,
  'locality',
  'Carlisle',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0072',
  'Great Britain',
  'Carlisle',
  None,
  'county_or_region',
  'Cumbria',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0073',
  'Great Britain',
  'Carlisle',
  None,
  'postcode',
  'CA2 4TS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0074',
  'Great Britain',
  'Carlisle',
  None,
  'venue_latitude',
  54.8622,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0075',
  'Great Britain',
  'Carlisle',
  None,
  'venue_longitude',
  -2.93358,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0076',
  'Great Britain',
  'Carlisle',
  None,
  'venue_reference_elevation_m',
  52,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102968',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0077',
  'Great Britain',
  'Carlisle',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1067',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'course_or_track_name',
  'Main Turf Course (conservative descriptive row)',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1068',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1069',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1070',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'racing_use',
  'Flat; chase; hurdle; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1071',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1072',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'course_geometry',
  'pear-shaped/round Carlisle course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1073',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'physical_relationship',
  'Old/New hurdle labels are held as candidates pending authoritative physical confirmation',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure'],
 ['P1074',
  'Great Britain',
  'Carlisle',
  'Main Turf Course (conservative descriptive row)',
  'gradients_or_elevation_characteristics',
  'notably uphill finish',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Carlisle Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/carlisle',
  '2026-08-11',
  'BHA 2015 distance tables prove named hurdle headings but not, by themselves, permanent independent physical courses. Assertion retained '
  'at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a separate '
  'permanent track.',
  'derived_from_verified_structure']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Carlisle',
  'OLD HURDLE / NHFR-OLD',
  'BHA 2015 Jump distance headings',
  'possible permanent alignment/course',
  'Official historic measurement labels exist, but no adequate modern authoritative physical-layout evidence was found to prove '
  'independent permanent courses or full-period continuity.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation'],
 ['Carlisle',
  'NEW HURDLE / NHFR-NEW',
  'BHA 2015 Jump distance headings',
  'possible permanent alignment/course',
  'The heading is real, but a race/distance heading alone is not enough to establish a separately governed permanent physical course.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Carlisle',
  'BHA 2015 measurement table names OLD HURDLE and NEW HURDLE; modern public descriptions do not explain their permanent physical status '
  'clearly.',
  'BHA versus modern secondary silence',
  'Could inflate/understate track count if headings are misread.',
  'Do not promote Old/New until authoritative physical confirmation.',
  'high']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [['Carlisle',
  'Do OLD HURDLE and NEW HURDLE in the 2015 BHA distance tables correspond to two independently maintained permanent physical hurdle '
  'courses throughout the relevant period?',
  'BHA headings prove named distinctions but current authoritative engineering/layout evidence was not found.',
  'BHA 2015 distance tables; modern course guide; wider web searching',
  'high — governed track count',
  'genuine_unresolved',
  'unresolved_after_research']],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Carlisle Racecourse is represented by 1 governed physical course/track/configuration row(s) in this research model: Main Turf Course (conservative descriptive row). BHA 2015 material names Old and New Hurdle headings; they are held out pending authoritative physical confirmation. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Carlisle'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Carlisle' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
