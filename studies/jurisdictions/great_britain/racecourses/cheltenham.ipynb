# %% [markdown]
# # Cheltenham
#
# Racecourse evidence notebook supporting Study 03. Run all cells to render the governed evidence record.

# %%
from pathlib import Path
p=Path.cwd()
while not (p/'studies').exists() and p!=p.parent: p=p.parent
exec((p/'studies/jurisdictions/great_britain/racecourses/_racecourse_notebook_support.py').read_text())
tables=render_venue('cheltenham')
