# %% [markdown]
# # Cheltenham
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Cheltenham**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Cheltenham`
# - Research-dossier venue label: `Cheltenham Racecourse`
# - Physical-model confidence: **high**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Cheltenham`
#
# Cheltenham Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Old Course; New Course; Cross Country Steeplechase Course. Official material supports Old, New and Cross Country as separate courses. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Cheltenham', 'Cheltenham']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Cheltenham',
  'Cheltenham Racecourse, Evesham Road, Cheltenham, Gloucestershire, GL50 4SH',
  'Prestbury / Cheltenham',
  'Gloucestershire',
  'GL50 4SH',
  51.92169,
  -2.05894,
  57,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Cheltenham',
  'racecourse_identity',
  'Cheltenham Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Cheltenham',
  'study03_source_labels',
  'Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Cheltenham',
  'aliases',
  'Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Cheltenham',
  'physical_venue_address',
  'Cheltenham Racecourse, Evesham Road, Cheltenham, Gloucestershire, GL50 4SH',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Contact Details',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['Cheltenham',
  'locality',
  'Prestbury / Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Cheltenham',
  'county_or_region',
  'Gloucestershire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Cheltenham',
  'postcode',
  'GL50 4SH',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Contact Details',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['Cheltenham',
  'venue_latitude',
  51.92169,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Cheltenham',
  'venue_longitude',
  -2.05894,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Cheltenham',
  'venue_reference_elevation_m',
  57,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Cheltenham',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Old Course; New Course; Cross Country Steeplechase Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Cheltenham',
  'Old Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; chase; NH Flat',
  'left-handed'],
 ['Cheltenham',
  'New Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; chase; NH Flat',
  'left-handed'],
 ['Cheltenham',
  'Cross Country Steeplechase Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'cross-country steeplechase',
  'mixed/twisting; not reduced to one handedness']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Old Course** — turf
# - **New Course** — turf
# - **Cross Country Steeplechase Course** — turf

# %% [markdown]
# ## Handedness
#
# - **Old Course** — left-handed
# - **New Course** — left-handed
# - **Cross Country Steeplechase Course** — mixed/twisting; not reduced to one handedness

# %% [markdown]
# ## Racing use
#
# - **Old Course** — hurdle; chase; NH Flat
# - **New Course** — hurdle; chase; NH Flat
# - **Cross Country Steeplechase Course** — cross-country steeplechase

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Cheltenham',
  'Old Course',
  'permanent Cheltenham course',
  'one of three officially named courses',
  None,
  None,
  None,
  None,
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  None,
  'verified_official'],
 ['Cheltenham',
  'New Course',
  'permanent Cheltenham course',
  'one of three officially named courses',
  None,
  None,
  None,
  None,
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  None,
  'verified_official'],
 ['Cheltenham',
  'Cross Country Steeplechase Course',
  'twisting cross-country layout',
  'separate officially named permanent course',
  None,
  None,
  None,
  'banks; ditches; rails; distinctive cross-country obstacles',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  None,
  'verified_official']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [['Cheltenham',
  '2026-03-30 onward',
  'drainage / remediation',
  'Old/New course home-straight area',
  'course affected by a hole/drainage problem; remaining fixtures cancelled',
  'drainage upgrade/remediation commenced',
  'The Jockey Club',
  'Cheltenham racecourse drainage update',
  'https://www.thejockeyclub.co.uk/cheltenham/media/news/2026/03/cheltenham-racecourse-update/',
  '2026-08-11',
  'verified_official',
  'In-scope intervention potentially relevant to physical/drainage model.']],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Cheltenham` → **Cheltenham** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0111',
  'Great Britain',
  'Cheltenham',
  None,
  'racecourse_identity',
  'Cheltenham Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0112',
  'Great Britain',
  'Cheltenham',
  None,
  'study03_source_labels',
  'Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0113',
  'Great Britain',
  'Cheltenham',
  None,
  'aliases',
  'Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0114',
  'Great Britain',
  'Cheltenham',
  None,
  'physical_venue_address',
  'Cheltenham Racecourse, Evesham Road, Cheltenham, Gloucestershire, GL50 4SH',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Contact Details',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['P0115',
  'Great Britain',
  'Cheltenham',
  None,
  'locality',
  'Prestbury / Cheltenham',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0116',
  'Great Britain',
  'Cheltenham',
  None,
  'county_or_region',
  'Gloucestershire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0117',
  'Great Britain',
  'Cheltenham',
  None,
  'postcode',
  'GL50 4SH',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Contact Details',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['P0118',
  'Great Britain',
  'Cheltenham',
  None,
  'venue_latitude',
  51.92169,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0119',
  'Great Britain',
  'Cheltenham',
  None,
  'venue_longitude',
  -2.05894,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0120',
  'Great Britain',
  'Cheltenham',
  None,
  'venue_reference_elevation_m',
  57,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793850',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0121',
  'Great Britain',
  'Cheltenham',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1075',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'course_or_track_name',
  'Old Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1076',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1077',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1078',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'racing_use',
  'hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1079',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1080',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'course_geometry',
  'permanent Cheltenham course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1081',
  'Great Britain',
  'Cheltenham',
  'Old Course',
  'physical_relationship',
  'one of three officially named courses',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1082',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'course_or_track_name',
  'New Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1083',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1084',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1085',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'racing_use',
  'hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1086',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1087',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'course_geometry',
  'permanent Cheltenham course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1088',
  'Great Britain',
  'Cheltenham',
  'New Course',
  'physical_relationship',
  'one of three officially named courses',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1089',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'course_or_track_name',
  'Cross Country Steeplechase Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1090',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1091',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1092',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'racing_use',
  'cross-country steeplechase',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1093',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'handedness',
  'mixed/twisting; not reduced to one handedness',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1094',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'course_geometry',
  'twisting cross-country layout',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1095',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'physical_relationship',
  'separate officially named permanent course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1096',
  'Great Britain',
  'Cheltenham',
  'Cross Country Steeplechase Course',
  'permanent_obstacles_or_distinctive_features',
  'banks; ditches; rails; distinctive cross-country obstacles',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Cheltenham Racecourse Map / Course Information',
  'https://www.thejockeyclub.co.uk/cheltenham/plan-your-day/racecourse-map/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Cheltenham',
  'Festival Old/New variants',
  'BHA distance / fixture wording',
  'event-specific route/rail/start variant',
  'Festival naming does not create a new permanent physical course beyond the officially governed Old and New courses.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'derived_from_verified_structure'],
 ['Cheltenham',
  '(Chute) / (round)',
  'BHA distance headings',
  'start/route configuration',
  'These describe how a race joins a governed course and are not separately recognised permanent courses.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Cheltenham',
  "BHA Heritage shows malformed postcode 'GL40 ASH'; current Jockey Club material uses GL50 4SH.",
  'BHA Heritage versus Jockey Club',
  'Official-source quality/address error.',
  'Use current official GL50 4SH; preserve the BHA anomaly.',
  'medium']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Cheltenham Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Old Course; New Course; Cross Country Steeplechase Course. Official material supports Old, New and Cross Country as separate courses. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Cheltenham'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Cheltenham' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
