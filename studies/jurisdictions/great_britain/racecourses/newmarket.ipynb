# %% [markdown]
# # Newmarket
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Newmarket**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Newmarket`, `Newmarket (July)`
# - Research-dossier venue label: `Newmarket Racecourses`
# - Physical-model confidence: **medium — taxonomy/detail unresolved**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Newmarket`
#
# Newmarket Racecourses is represented by 2 governed physical course/track/configuration row(s) in this research model: Rowley Mile Course; July Course. Official Jockey Club material describes Rowley Mile and July Course as two racecourses; other named components are held at lower/candidate level. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Newmarket', 'Newmarket'], ['Great Britain', 'Newmarket (July)', 'Newmarket']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Newmarket',
  'Newmarket Racecourses, Newmarket, Suffolk, CB8 0TG',
  'Newmarket',
  'Suffolk',
  'CB8 0TG',
  52.23673,
  0.37299,
  34,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Newmarket',
  'racecourse_identity',
  'Newmarket Racecourses',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'derived_from_verified_structure'],
 ['Newmarket',
  'study03_source_labels',
  'Newmarket; Newmarket (July)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Newmarket',
  'aliases',
  'Newmarket; Newmarket Racecourse',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Newmarket',
  'physical_venue_address',
  'Newmarket Racecourses, Newmarket, Suffolk, CB8 0TG',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Newmarket',
  'locality',
  'Newmarket',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Newmarket',
  'county_or_region',
  'Suffolk',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'derived_from_verified_location'],
 ['Newmarket',
  'postcode',
  'CB8 0TG',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Newmarket',
  'venue_latitude',
  52.23673,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Newmarket',
  'venue_longitude',
  0.37299,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Newmarket',
  'venue_reference_elevation_m',
  34,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Newmarket',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Rowley Mile Course; July Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Newmarket',
  'Rowley Mile Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'Flat',
  'predominantly straight; right-turn access for longer routes'],
 ['Newmarket',
  'July Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'Flat',
  'right-turn route into long straight']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Rowley Mile Course** — turf
# - **July Course** — turf

# %% [markdown]
# ## Handedness
#
# - **Rowley Mile Course** — predominantly straight; right-turn access for longer routes
# - **July Course** — right-turn route into long straight

# %% [markdown]
# ## Racing use
#
# - **Rowley Mile Course** — Flat
# - **July Course** — Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Newmarket',
  'Rowley Mile Course',
  "one of Newmarket's two official racecourses",
  'paired with the separate July Course',
  None,
  None,
  'includes The Dip',
  None,
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  None,
  'verified_official'],
 ['Newmarket',
  'July Course',
  "one of Newmarket's two official racecourses",
  'paired with the separate Rowley Mile Course',
  None,
  None,
  None,
  None,
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  None,
  'verified_official']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Newmarket`, `Newmarket (July)` → **Newmarket** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0375',
  'Great Britain',
  'Newmarket',
  None,
  'racecourse_identity',
  'Newmarket Racecourses',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'derived_from_verified_structure'],
 ['P0376',
  'Great Britain',
  'Newmarket',
  None,
  'study03_source_labels',
  'Newmarket; Newmarket (July)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0377',
  'Great Britain',
  'Newmarket',
  None,
  'aliases',
  'Newmarket; Newmarket Racecourse',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0378',
  'Great Britain',
  'Newmarket',
  None,
  'physical_venue_address',
  'Newmarket Racecourses, Newmarket, Suffolk, CB8 0TG',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0379',
  'Great Britain',
  'Newmarket',
  None,
  'locality',
  'Newmarket',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0380',
  'Great Britain',
  'Newmarket',
  None,
  'county_or_region',
  'Suffolk',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'derived_from_verified_location'],
 ['P0381',
  'Great Britain',
  'Newmarket',
  None,
  'postcode',
  'CB8 0TG',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0382',
  'Great Britain',
  'Newmarket',
  None,
  'venue_latitude',
  52.23673,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0383',
  'Great Britain',
  'Newmarket',
  None,
  'venue_longitude',
  0.37299,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0384',
  'Great Britain',
  'Newmarket',
  None,
  'venue_reference_elevation_m',
  34,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/28793844',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0385',
  'Great Britain',
  'Newmarket',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1248',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'course_or_track_name',
  'Rowley Mile Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1249',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1250',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1251',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'racing_use',
  'Flat',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1252',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'handedness',
  'predominantly straight; right-turn access for longer routes',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1253',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'course_geometry',
  "one of Newmarket's two official racecourses",
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1254',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'physical_relationship',
  'paired with the separate July Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1255',
  'Great Britain',
  'Newmarket',
  'Rowley Mile Course',
  'gradients_or_elevation_characteristics',
  'includes The Dip',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1256',
  'Great Britain',
  'Newmarket',
  'July Course',
  'course_or_track_name',
  'July Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1257',
  'Great Britain',
  'Newmarket',
  'July Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1258',
  'Great Britain',
  'Newmarket',
  'July Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1259',
  'Great Britain',
  'Newmarket',
  'July Course',
  'racing_use',
  'Flat',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1260',
  'Great Britain',
  'Newmarket',
  'July Course',
  'handedness',
  'right-turn route into long straight',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1261',
  'Great Britain',
  'Newmarket',
  'July Course',
  'course_geometry',
  "one of Newmarket's two official racecourses",
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1262',
  'Great Britain',
  'Newmarket',
  'July Course',
  'physical_relationship',
  'paired with the separate Rowley Mile Course',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'About Newmarket Racecourses',
  'https://www.thejockeyclub.co.uk/newmarket/about/',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Newmarket',
  'Cesarewitch Course',
  'Racing TV technical description',
  'named route/course component',
  'Secondary technical material names it, but official Jockey Club material frames Newmarket as two racecourses. Retain below top-level '
  'governed inventory pending authoritative physical taxonomy.',
  'Racing TV',
  'Newmarket Rowley Mile Course Guide',
  'https://www.racingtv.com/racecourses/uk/newmarket-rowley-mile',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation'],
 ['Newmarket',
  'Beacon Course',
  'Racing TV technical description',
  'named route/course component',
  'Likely a permanent longer-distance branch/route, but it is not promoted to the same level as Rowley Mile and July without authoritative '
  'taxonomy.',
  'Racing TV',
  'Newmarket Rowley Mile Course Guide',
  'https://www.racingtv.com/racecourses/uk/newmarket-rowley-mile',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation'],
 ['Newmarket',
  'Bunbury Mile',
  'Racing TV July Course description',
  'named straight/component',
  'A named mile/straight component used by routes; not established as a third Newmarket racecourse.',
  'Racing TV',
  'Newmarket July Course Guide',
  'https://www.racingtv.com/racecourses/uk/newmarket-july',
  '2026-08-11',
  'derived_from_verified_structure'],
 ['Newmarket',
  'Town Plate / Round Course route',
  'Jockey Club special-event material',
  'historic/special route',
  'A historic/special route does not automatically become a normal permanent constituent course in the 2015–2026 governed model.',
  'The Jockey Club',
  'Newmarket Town Plate',
  'https://www.thejockeyclub.co.uk/newmarket/events-tickets/newmarket-town-plate/',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Newmarket',
  'Official operator says two racecourses; secondary technical guides additionally name Cesarewitch, Beacon and Bunbury components.',
  'Jockey Club versus Racing TV terminology',
  "Every occurrence of the word 'course' cannot safely become a top-level physical track.",
  'Govern Rowley Mile and July; hold the other names as lower-level candidates/components.',
  'high']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [['Newmarket',
  'How should Beacon Course and Cesarewitch Course be represented in a governed hierarchy below Rowley Mile and July Course?',
  'Secondary technical sources name them; official high-level material says Newmarket has two racecourses.',
  'Jockey Club; Racing TV; wider web search',
  'high — taxonomy/hierarchy',
  'genuine_unresolved',
  'unresolved_after_research']],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Newmarket Racecourses is represented by 2 governed physical course/track/configuration row(s) in this research model: Rowley Mile Course; July Course. Official Jockey Club material describes Rowley Mile and July Course as two racecourses; other named components are held at lower/candidate level. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Newmarket'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Newmarket' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
