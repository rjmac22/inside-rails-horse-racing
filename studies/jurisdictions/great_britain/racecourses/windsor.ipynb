# %% [markdown]
# # Windsor
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Windsor**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Windsor`
# - Research-dossier venue label: `Royal Windsor Racecourse`
# - Physical-model confidence: **medium — taxonomy/detail unresolved**
# - Key temporal boundary: 2024/25 Jump Extended Left-Hand Oval: 2024-12-15 → 2025-01-19; 2025/26 Jump Figure-of-Eight Configuration: 2025-11-23 → 2026-05-27.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Windsor`
#
# Royal Windsor Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Traditional Figure-of-Eight Turf Course; 2024/25 Jump Extended Left-Hand Oval; 2025/26 Jump Figure-of-Eight Configuration. A real in-scope layout boundary exists: 2024/25 Jumps used an extended left-handed oval; 2025/26 reverted to the traditional figure-eight. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Windsor', 'Windsor']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Windsor',
  'Royal Windsor Racecourse, Maidenhead Road, Windsor, Berkshire, SL4 5JJ',
  'Windsor',
  'Berkshire',
  'SL4 5JJ',
  51.4905,
  -0.6313,
  20,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Windsor',
  'racecourse_identity',
  'Royal Windsor Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Windsor',
  'study03_source_labels',
  'Windsor',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Windsor',
  'aliases',
  'Windsor; Royal Windsor',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Windsor',
  'physical_venue_address',
  'Royal Windsor Racecourse, Maidenhead Road, Windsor, Berkshire, SL4 5JJ',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['Windsor',
  'locality',
  'Windsor',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Windsor',
  'county_or_region',
  'Berkshire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Windsor',
  'postcode',
  'SL4 5JJ',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['Windsor',
  'venue_latitude',
  51.4905,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Windsor',
  'venue_longitude',
  -0.6313,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Windsor',
  'venue_reference_elevation_m',
  20,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Windsor',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Traditional Figure-of-Eight Turf Course; 2024/25 Jump Extended Left-Hand Oval; 2025/26 Jump Figure-of-Eight Configuration**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'Flat',
  'figure-eight / mixed turns'],
 ['Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'verified_official',
  'temporal course configuration',
  '2024-12-15',
  '2025-01-19',
  'turf',
  'hurdle; chase',
  'left-handed'],
 ['Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'verified_official',
  'temporal course configuration',
  '2025-11-23',
  '2026-05-27',
  'turf',
  'hurdle; chase',
  'figure-eight / mixed turns']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Traditional Figure-of-Eight Turf Course** — turf
# - **2024/25 Jump Extended Left-Hand Oval** — turf
# - **2025/26 Jump Figure-of-Eight Configuration** — turf

# %% [markdown]
# ## Handedness
#
# - **Traditional Figure-of-Eight Turf Course** — figure-eight / mixed turns
# - **2024/25 Jump Extended Left-Hand Oval** — left-handed
# - **2025/26 Jump Figure-of-Eight Configuration** — figure-eight / mixed turns

# %% [markdown]
# ## Racing use
#
# - **Traditional Figure-of-Eight Turf Course** — Flat
# - **2024/25 Jump Extended Left-Hand Oval** — hurdle; chase
# - **2025/26 Jump Figure-of-Eight Configuration** — hurdle; chase

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'traditional figure-eight turf layout',
  'base Flat course; later reused for Jumps after 2025 reversion',
  None,
  None,
  None,
  None,
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  None,
  'verified_official'],
 ['Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'continuous left-handed oval using newly developed track areas; no crossover',
  'season-specific physical racing configuration distinct from the traditional figure-eight',
  None,
  None,
  None,
  None,
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved.',
  'verified_official'],
 ['Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'reversion to full traditional figure-eight with Jumps obstacle layout',
  'successor to the 2024/25 extended left-handed oval',
  None,
  None,
  None,
  None,
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing Returns',
  'https://www.windsor-racecourse.co.uk/racing-highlights/jump-racing-returns',
  '2026-08-11',
  'Official Windsor material states the 2025/26 jumps season first fixture was Sunday 23 November 2025 and that the figure-of-eight was '
  'restored.',
  'verified_official']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [['Windsor',
  '2024-12-15',
  'course-layout change',
  'Jump configuration',
  'no Jump racing in preceding years / traditional figure-eight not used for initial return',
  'new extended continuous left-handed oval with widened back straight and no crossover',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'verified_official',
  'Major physical-model boundary.'],
 ['Windsor',
  '2025-11-23',
  'course-layout change',
  'Jump configuration',
  'extended left-handed oval used for 2024/25 return',
  'reversion to full figure-eight for 2025/26 Jumps season with rail/drainage works',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing Returns',
  'https://www.windsor-racecourse.co.uk/racing-highlights/jump-racing-returns',
  '2026-08-11',
  'verified_official',
  'Major physical-model boundary.']],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Windsor` → **Windsor** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0595',
  'Great Britain',
  'Windsor',
  None,
  'racecourse_identity',
  'Royal Windsor Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0596',
  'Great Britain',
  'Windsor',
  None,
  'study03_source_labels',
  'Windsor',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0597',
  'Great Britain',
  'Windsor',
  None,
  'aliases',
  'Windsor; Royal Windsor',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0598',
  'Great Britain',
  'Windsor',
  None,
  'physical_venue_address',
  'Royal Windsor Racecourse, Maidenhead Road, Windsor, Berkshire, SL4 5JJ',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['P0599',
  'Great Britain',
  'Windsor',
  None,
  'locality',
  'Windsor',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0600',
  'Great Britain',
  'Windsor',
  None,
  'county_or_region',
  'Berkshire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0601',
  'Great Britain',
  'Windsor',
  None,
  'postcode',
  'SL4 5JJ',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['P0602',
  'Great Britain',
  'Windsor',
  None,
  'venue_latitude',
  51.4905,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0603',
  'Great Britain',
  'Windsor',
  None,
  'venue_longitude',
  -0.6313,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0604',
  'Great Britain',
  'Windsor',
  None,
  'venue_reference_elevation_m',
  20,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103316',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0605',
  'Great Britain',
  'Windsor',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1312',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'course_or_track_name',
  'Traditional Figure-of-Eight Turf Course',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1313',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1314',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1315',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'racing_use',
  'Flat',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1316',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'handedness',
  'figure-eight / mixed turns',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1317',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'course_geometry',
  'traditional figure-eight turf layout',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1318',
  'Great Britain',
  'Windsor',
  'Traditional Figure-of-Eight Turf Course',
  'physical_relationship',
  'base Flat course; later reused for Jumps after 2025 reversion',
  '2015-01-01',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1319',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'course_or_track_name',
  '2024/25 Jump Extended Left-Hand Oval',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1320',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'entity_type',
  'temporal course configuration',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1321',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'surface',
  'turf',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1322',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'racing_use',
  'hurdle; chase',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1323',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'handedness',
  'left-handed',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1324',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'course_geometry',
  'continuous left-handed oval using newly developed track areas; no crossover',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1325',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'physical_relationship',
  'season-specific physical racing configuration distinct from the traditional figure-eight',
  '2024-12-15',
  '2025 — exact final use unresolved',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing To Return To Royal Windsor Racecourse',
  'https://www.windsor-racecourse.co.uk/news/racing/jump-racing-to-return-to-royal-windsor-racecourse',
  '2026-08-11',
  'Official return-to-Jumps announcement establishes the new oval and first fixture; exact last-use date remains unresolved. Assertion '
  'retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically interpreted as a '
  'separate permanent track.',
  'verified_official'],
 ['P1326',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'course_or_track_name',
  '2025/26 Jump Figure-of-Eight Configuration',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1327',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'entity_type',
  'temporal course configuration',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1328',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'surface',
  'turf',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1329',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'racing_use',
  'hurdle; chase',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1330',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'handedness',
  'figure-eight / mixed turns',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1331',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'course_geometry',
  'reversion to full traditional figure-eight with Jumps obstacle layout',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1332',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'physical_relationship',
  'successor to the 2024/25 extended left-handed oval',
  '2025-11 (first exact fixture date not established in this pass)',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Windsor to revert to full figure-of-eight course for 2025/26 jumps season',
  'https://www.windsor-racecourse.co.uk/news/racing/windsor-to-revert-to-full-figure-of-eight-course-for-2025-26-jumps-season',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['IR_WIND_001',
  'Great Britain',
  'Windsor',
  '2024/25 Jump Extended Left-Hand Oval',
  'valid_to',
  '2025-01-19',
  '2024-12-15',
  '2025-01-19',
  'Royal Windsor Racecourse / Arena Racing Company',
  '2025 Racing Dates Announced: Secure Your Tickets Now!',
  'https://www.windsor-racecourse.co.uk/news/racing/2025-racing-dates-announced-secure-your-tickets-now',
  '2026-08-11',
  'Official 2025 fixture announcement identifies Windsor jumps fixtures on 17 and 19 January 2025; 19 January is the final fixture of the '
  '2024/25 return configuration before the later announced reversion.',
  'derived_from_verified_schedule'],
 ['IR_WIND_002',
  'Great Britain',
  'Windsor',
  '2025/26 Jump Figure-of-Eight Configuration',
  'valid_from',
  '2025-11-23',
  '2025-11-23',
  '2026-05-27',
  'Royal Windsor Racecourse / Arena Racing Company',
  'Jump Racing Returns',
  'https://www.windsor-racecourse.co.uk/racing-highlights/jump-racing-returns',
  '2026-08-11',
  'Official Windsor page states the restored figure-of-eight jumps season would host its first fixture on Sunday 23 November 2025.',
  'verified_official']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Windsor',
  'The physical Jump layout changes within scope: 2024/25 extended left oval, 2025/26 figure-eight.',
  'official Windsor announcements across seasons',
  'A timeless Windsor course row would erase a real redevelopment boundary.',
  'Use temporal configuration rows.',
  'high']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Royal Windsor Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: Traditional Figure-of-Eight Turf Course; 2024/25 Jump Extended Left-Hand Oval; 2025/26 Jump Figure-of-Eight Configuration. A real in-scope layout boundary exists: 2024/25 Jumps used an extended left-handed oval; 2025/26 reverted to the traditional figure-eight. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Windsor'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Windsor' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
