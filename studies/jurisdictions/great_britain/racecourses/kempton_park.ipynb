# %% [markdown]
# # Kempton Park
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Kempton Park**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Kempton`, `Kempton (AW)`
# - Research-dossier venue label: `Kempton Park Racecourse`
# - Physical-model confidence: **high**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Kempton Park`
#
# Kempton Park Racecourse is represented by 2 governed physical course/track/configuration row(s) in this research model: All-Weather Polytrack Track; Turf Jumps Course. One venue containing a Polytrack all-weather course and a turf Jumps course; inner/outer AW loops and seasonal starts are components/configurations. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Kempton', 'Kempton Park'], ['Great Britain', 'Kempton (AW)', 'Kempton Park']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Kempton Park',
  'Kempton Park Racecourse, Sunbury-on-Thames, TW16 5AQ',
  'Sunbury-on-Thames',
  'Surrey / historic Middlesex',
  'TW16 5AQ',
  51.41861,
  -0.39814,
  7,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Kempton Park',
  'racecourse_identity',
  'Kempton Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Kempton Park',
  'study03_source_labels',
  'Kempton; Kempton (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Kempton Park',
  'aliases',
  'Kempton; Kempton Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Kempton Park',
  'physical_venue_address',
  'Kempton Park Racecourse, Sunbury-on-Thames, TW16 5AQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Kempton Park',
  'locality',
  'Sunbury-on-Thames',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Kempton Park',
  'county_or_region',
  'Surrey / historic Middlesex',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Kempton Park',
  'postcode',
  'TW16 5AQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Kempton Park',
  'venue_latitude',
  51.41861,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Kempton Park',
  'venue_longitude',
  -0.39814,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Kempton Park',
  'venue_reference_elevation_m',
  7,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Kempton Park',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **All-Weather Polytrack Track; Turf Jumps Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Kempton Park',
  'All-Weather Polytrack Track',
  'verified_secondary_technical',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Polytrack',
  'Flat; AW',
  'right-handed'],
 ['Kempton Park',
  'Turf Jumps Course',
  'verified_secondary_technical',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; chase; NH Flat',
  'right-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **All-Weather Polytrack Track** — Polytrack
# - **Turf Jumps Course** — turf

# %% [markdown]
# ## Handedness
#
# - **All-Weather Polytrack Track** — right-handed
# - **Turf Jumps Course** — right-handed

# %% [markdown]
# ## Racing use
#
# - **All-Weather Polytrack Track** — Flat; AW
# - **Turf Jumps Course** — hurdle; chase; NH Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Kempton Park',
  'All-Weather Polytrack Track',
  'all-weather oval with inner/outer loop use',
  'separate synthetic track within Kempton Park',
  None,
  None,
  None,
  None,
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  None,
  'verified_secondary_technical'],
 ['Kempton Park',
  'Turf Jumps Course',
  'National Hunt turf circuit',
  'separate from the all-weather track',
  None,
  None,
  None,
  None,
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  None,
  'verified_secondary_technical']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Kempton`, `Kempton (AW)` → **Kempton Park** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0287',
  'Great Britain',
  'Kempton Park',
  None,
  'racecourse_identity',
  'Kempton Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0288',
  'Great Britain',
  'Kempton Park',
  None,
  'study03_source_labels',
  'Kempton; Kempton (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0289',
  'Great Britain',
  'Kempton Park',
  None,
  'aliases',
  'Kempton; Kempton Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0290',
  'Great Britain',
  'Kempton Park',
  None,
  'physical_venue_address',
  'Kempton Park Racecourse, Sunbury-on-Thames, TW16 5AQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0291',
  'Great Britain',
  'Kempton Park',
  None,
  'locality',
  'Sunbury-on-Thames',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0292',
  'Great Britain',
  'Kempton Park',
  None,
  'county_or_region',
  'Surrey / historic Middlesex',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0293',
  'Great Britain',
  'Kempton Park',
  None,
  'postcode',
  'TW16 5AQ',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0294',
  'Great Britain',
  'Kempton Park',
  None,
  'venue_latitude',
  51.41861,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0295',
  'Great Britain',
  'Kempton Park',
  None,
  'venue_longitude',
  -0.39814,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0296',
  'Great Britain',
  'Kempton Park',
  None,
  'venue_reference_elevation_m',
  7,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102980',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0297',
  'Great Britain',
  'Kempton Park',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1169',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'course_or_track_name',
  'All-Weather Polytrack Track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1170',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1171',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'surface',
  'Polytrack',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1172',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'racing_use',
  'Flat; AW',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1173',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1174',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'course_geometry',
  'all-weather oval with inner/outer loop use',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1175',
  'Great Britain',
  'Kempton Park',
  'All-Weather Polytrack Track',
  'physical_relationship',
  'separate synthetic track within Kempton Park',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1176',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'course_or_track_name',
  'Turf Jumps Course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1177',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1178',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1179',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'racing_use',
  'hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1180',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1181',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'course_geometry',
  'National Hunt turf circuit',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1182',
  'Great Britain',
  'Kempton Park',
  'Turf Jumps Course',
  'physical_relationship',
  'separate from the all-weather track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Kempton Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/kempton-park',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Kempton Park',
  'Winter Start / Summer Start',
  'BHA distance headings',
  'start configuration',
  'Different start positions do not create separate permanent tracks.',
  'British Horseracing Authority',
  '2015 Jump race distance measurement results',
  'https://www.britishhorseracing.com/wp-content/uploads/2015/05/Jump-distance-changes-1-June-2015.pdf',
  '2026-08-11',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Kempton Park Racecourse is represented by 2 governed physical course/track/configuration row(s) in this research model: All-Weather Polytrack Track; Turf Jumps Course. One venue containing a Polytrack all-weather course and a turf Jumps course; inner/outer AW loops and seasonal starts are components/configurations. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Kempton Park'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Kempton Park' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
