# %% [markdown]
# # Aintree
#
# First-pass racecourse evidence notebook for the Inside Rails British racecourse/course research programme.
#
# This notebook is deliberately concise. It establishes the racecourse identity, constituent course inventory, source-label mapping, venue location metadata and explicit provenance needed by current research. Unsupported points remain unresolved rather than being filled from general racing knowledge.

# %% [markdown]
# ## Scope
#
# Racecourse: **Aintree**
# Jurisdiction: **Great Britain**
# Study period inherited from the cross-racecourse study: **2015-01-01 to 2026-05-27**
#
# This venue notebook supplements cross-racecourse Study 03. Study 03 remains responsible for the national racecourse inventory and source-label → racecourse mapping; this notebook is the durable detailed evidence record for Aintree.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Aintree`
#
# Aintree is treated as one stable racecourse/venue entity. Constituent courses are modelled separately rather than promoted to separate racecourse identities.

# %% [markdown]
# ## Source-data labels
#
# The governed Great Britain mapping established in Study 03 contains one source label for this venue: `Aintree` → **Aintree**.
#
# The source label is not a complete course inventory: the same label covers multiple separately recognised Aintree courses.

# %%
import pandas as pd

source_label_mapping = pd.DataFrame([
    {"jurisdiction": "Great Britain", "candidate_course_label": "Aintree", "racecourse_identity": "Aintree"}
])
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is modelled at **racecourse/venue level**, not repeated as though each constituent course were a separate venue.
#
# The official Jockey Club address is used for address/locality/postcode. The current latitude, longitude and single reference elevation are retained as **secondary geospatial reference values**, not as surveyed course-centre coordinates or an elevation profile. `Europe/London` is the IANA timezone derived from the verified Great Britain location.

# %%
location_metadata = pd.DataFrame([{
    "racecourse_identity": "Aintree",
    "address": "Aintree Racecourse, Ormskirk Road, Aintree, Merseyside, L9 5AS",
    "locality": "Aintree",
    "county_or_region": "Merseyside",
    "postcode": "L9 5AS",
    "latitude": 53.4765,
    "longitude": -2.94652,
    "elevation_m": 23,
    "iana_timezone": "Europe/London",
    "coordinate_status": "secondary_venue_point",
    "elevation_status": "secondary_venue_reference",
}])
location_metadata

# %%
location_provenance = pd.DataFrame([
    {
        "racecourse_identity": "Aintree",
        "field": "address/locality/region/postcode",
        "value": "Aintree Racecourse, Ormskirk Road, Aintree, Merseyside, L9 5AS",
        "source_authority": "The Jockey Club",
        "source_title": "Contact Us | Aintree Racecourse",
        "source_url": "https://www.thejockeyclub.co.uk/aintree/about/contact/",
        "accessed_date": "2026-08-10",
        "evidence_note": "Official racecourse contact page supplies the venue address.",
        "verification_status": "verified_official",
    },
    {
        "racecourse_identity": "Aintree",
        "field": "latitude/longitude",
        "value": "53.4765, -2.94652",
        "source_authority": "Mapcarta (based on OpenStreetMap / GeoNames)",
        "source_title": "Aintree Racecourse Map",
        "source_url": "https://mapcarta.com/28793848",
        "accessed_date": "2026-08-10",
        "evidence_note": "Secondary venue point for spatial linkage; not represented as a surveyed centroid, start point or course-specific coordinate.",
        "verification_status": "secondary_geospatial_reference",
    },
    {
        "racecourse_identity": "Aintree",
        "field": "elevation_m",
        "value": "23",
        "source_authority": "Mapcarta (based on GeoNames / OpenStreetMap)",
        "source_title": "Aintree Racecourse Map",
        "source_url": "https://mapcarta.com/28793848",
        "accessed_date": "2026-08-10",
        "evidence_note": "Single venue reference elevation only; not a course elevation profile.",
        "verification_status": "secondary_geospatial_reference",
    },
    {
        "racecourse_identity": "Aintree",
        "field": "iana_timezone",
        "value": "Europe/London",
        "source_authority": "IANA Time Zone Database",
        "source_title": "How to Read the tz Database",
        "source_url": "https://www.iana.org/time-zones/tz-how-to",
        "accessed_date": "2026-08-10",
        "evidence_note": "IANA documents Europe/London for UK civil time; assigned from the verified Great Britain venue location.",
        "verification_status": "derived_from_verified_location",
    },
])
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Authoritative Jockey Club material separately names the **Grand National Course**, **Mildmay Course**, and **Hurdle Course**. These are therefore represented as three constituent course entities for the current first-pass inventory.

# %%
course_inventory = pd.DataFrame([
    {"racecourse_identity": "Aintree", "course_or_track_name": "Grand National Course", "surface": "Turf", "primary_use": "Steeplechase / National fences", "handedness": "Left-handed"},
    {"racecourse_identity": "Aintree", "course_or_track_name": "Mildmay Course", "surface": "Turf", "primary_use": "Conventional chase", "handedness": "Left-handed"},
    {"racecourse_identity": "Aintree", "course_or_track_name": "Hurdle Course", "surface": "Turf", "primary_use": "Hurdle", "handedness": "Left-handed"},
])
course_inventory

# %% [markdown]
# ## Surface
#
# Current first-pass classification: **Turf** for all three course entities. This is supported separately from course identity by Jockey Club material describing the turf/grass racing surface at Aintree; it is not inferred merely from Aintree being a jumps venue.
#
# ## Handedness
#
# Current first-pass classification: **Left-handed** for all three course entities. The provenance is recorded separately below rather than treated as a generic venue fact that can automatically be copied to every possible future configuration.
#
# ## Racing use
#
# - **Grand National Course** — specialist steeplechase course using Aintree's distinctive National fences.
# - **Mildmay Course** — conventional chase course.
# - **Hurdle Course** — separately recognised hurdle course.

# %% [markdown]
# ## Course layout and physical characteristics
#
# The current first pass establishes only the distinctions needed for course identity and the characteristics above. No additional permanent sub-courses, rail-position variants, dimensions, gradients, fence counts or geometric descriptions are promoted here without separately evidenced need.
#
# ## Historical changes
#
# No additional historical course-identity or surface transition is promoted in this first pass. This is not a claim that Aintree has never changed; it means only that no further historical change is required by the evidence transferred into this template notebook at this stage.
#
# ## Source mapping
#
# One source label (`Aintree`) maps to one racecourse identity (**Aintree**) but at least three separately recognised constituent courses. This is a concrete example of why `source course label ≠ governed course inventory`.

# %% [markdown]
# ## Evidence and provenance
#
# Each characteristic is recorded as its own evidence-backed assertion. A course-identity citation is not automatically treated as proof of surface, handedness or racing use. `valid_from` and `valid_to` remain null where the reviewed evidence does not establish exact temporal boundaries.

# %%
rows = []
courses = ["Grand National Course", "Mildmay Course", "Hurdle Course"]

for course in courses:
    rows.append({
        "jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": course,
        "characteristic": "course_identity", "value": course, "valid_from": None, "valid_to": None,
        "source_authority": "The Jockey Club",
        "source_title": "Going news & non-runners on Grand National Day",
        "source_url": "https://www.thejockeyclub.co.uk/aintree/media/press-releases/2019/04/going-news--non-runners-on-grand-national-day/",
        "accessed_date": "2026-08-10",
        "evidence_note": "Official Aintree going report separately names the Grand National Course and the Mildmay and Hurdle Courses.",
        "verification_status": "verified",
    })

for course in courses:
    rows.append({
        "jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": course,
        "characteristic": "surface", "value": "Turf", "valid_from": None, "valid_to": None,
        "source_authority": "The Jockey Club",
        "source_title": "Horse Welfare - turf and ground | Aintree Racecourse",
        "source_url": "https://www.thejockeyclub.co.uk/aintree/horse-welfare/horse-welfare-turf-ground/",
        "accessed_date": "2026-08-10",
        "evidence_note": "Jockey Club Aintree welfare material describes the racing turf/grass and its preparation across the circuit.",
        "verification_status": "verified",
    })

for course in courses:
    rows.append({
        "jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": course,
        "characteristic": "handedness", "value": "Left-handed", "valid_from": None, "valid_to": None,
        "source_authority": "The Jockey Club",
        "source_title": "Five horses to look out for at the Randox Health Grand National Festival",
        "source_url": "https://www.thejockeyclub.co.uk/events-tickets/festivals/randox-health-grand-national-guide/five-horses-to-look-out-for-at-the-randox-health-grand-national-festival/",
        "accessed_date": "2026-08-10",
        "evidence_note": "Jockey Club editorial describes the Aintree track as left-handed.",
        "verification_status": "verified",
    })

rows.extend([
    {"jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": "Grand National Course", "characteristic": "primary_use", "value": "Steeplechase / National fences", "valid_from": None, "valid_to": None, "source_authority": "The Jockey Club", "source_title": "The History of the Grand National", "source_url": "https://www.thejockeyclub.co.uk/aintree/about/history/", "accessed_date": "2026-08-10", "evidence_note": "Jockey Club history material identifies the Grand National as Aintree's defining steeplechase and distinguishes conventional fences and hurdles on the current course.", "verification_status": "verified"},
    {"jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": "Mildmay Course", "characteristic": "primary_use", "value": "Conventional chase", "valid_from": None, "valid_to": None, "source_authority": "The Jockey Club", "source_title": "Treble-seeking Walk In The Mill heads 15 for William Hill Becher Handicap Chase", "source_url": "https://www.thejockeyclub.co.uk/aintree/media/press-releases/2020/12/becher-chase-2020/", "accessed_date": "2026-08-10", "evidence_note": "Official Aintree material identifies a chase staged over the Mildmay Course and separately reports the Mildmay chase course and Hurdle Course.", "verification_status": "verified"},
    {"jurisdiction": "Great Britain", "racecourse_identity": "Aintree", "course_or_track_name": "Hurdle Course", "characteristic": "primary_use", "value": "Hurdle", "valid_from": None, "valid_to": None, "source_authority": "The Jockey Club", "source_title": "Treble-seeking Walk In The Mill heads 15 for William Hill Becher Handicap Chase", "source_url": "https://www.thejockeyclub.co.uk/aintree/media/press-releases/2020/12/becher-chase-2020/", "accessed_date": "2026-08-10", "evidence_note": "Official Aintree going material explicitly distinguishes the Hurdle Course from the Mildmay chase course.", "verification_status": "verified"},
])

course_characteristic_provenance = pd.DataFrame(rows, columns=[
    "jurisdiction", "racecourse_identity", "course_or_track_name", "characteristic", "value",
    "valid_from", "valid_to", "source_authority", "source_title", "source_url",
    "accessed_date", "evidence_note", "verification_status",
])
course_characteristic_provenance

# %%
assert set(course_inventory["course_or_track_name"]) == {"Grand National Course", "Mildmay Course", "Hurdle Course"}
assert source_label_mapping["candidate_course_label"].tolist() == ["Aintree"]
assert source_label_mapping["racecourse_identity"].tolist() == ["Aintree"]
assert set(course_characteristic_provenance["course_or_track_name"]) == set(course_inventory["course_or_track_name"])
assert course_characteristic_provenance["source_url"].notna().all()
assert course_characteristic_provenance["verification_status"].eq("verified").all()
assert location_metadata["racecourse_identity"].tolist() == ["Aintree"]
assert location_metadata["iana_timezone"].tolist() == ["Europe/London"]
assert location_provenance["source_url"].str.startswith("http").all()
assert set(location_provenance["field"]) == {"address/locality/region/postcode", "latitude/longitude", "elevation_m", "iana_timezone"}
print("Aintree first-pass inventory, location and provenance checks passed.")

# %% [markdown]
# ## Unresolved questions
#
# - Whether later database governance should model more detailed physical geometry or overlap between the Mildmay and Hurdle routes.
# - Whether stable temporal boundaries are needed for the current course identities or characteristics.
# - Whether future analytical questions require finer course configurations beyond the three entities established here.
# - How temporary rail movements should be represented if a later study requires them; they should not automatically create permanent course identities.
# - Whether the current secondary venue coordinate should later be replaced by a defined authoritative/surveyed reference point for spatial joins.
# - Whether elevation should later be represented by course-specific elevation profiles rather than a single venue reference elevation.
#
# ## Findings from later studies
#
# _None yet._
#
# Add later findings here only when another study establishes something material about Aintree that belongs in the durable venue evidence record.
