# %% [markdown]
# # Sandown Park
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Sandown Park**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Sandown`
# - Research-dossier venue label: `Sandown Park Racecourse`
# - Physical-model confidence: **medium**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Sandown Park`
#
# Sandown Park Racecourse is represented by 1 governed physical course/track/configuration row(s) in this research model: Main Turf Course (conservative descriptive row). One broad turf complex governed conservatively; candidate hurdle/chase alignments remain unpromoted. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Sandown', 'Sandown Park']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Sandown Park',
  'Sandown Park Racecourse, Portsmouth Road, Esher, Surrey, KT10 9AJ',
  'Esher',
  'Surrey',
  'KT10 9AJ',
  51.37705,
  -0.36355,
  18,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Sandown Park',
  'racecourse_identity',
  'Sandown Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Sandown Park',
  'study03_source_labels',
  'Sandown',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Sandown Park',
  'aliases',
  'Sandown; Sandown Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Sandown Park',
  'physical_venue_address',
  'Sandown Park Racecourse, Portsmouth Road, Esher, Surrey, KT10 9AJ',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Sandown Park Contact',
  'https://www.thejockeyclub.co.uk/sandown/about/contact/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['Sandown Park',
  'locality',
  'Esher',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Sandown Park',
  'county_or_region',
  'Surrey',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Sandown Park',
  'postcode',
  'KT10 9AJ',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Sandown Park Contact',
  'https://www.thejockeyclub.co.uk/sandown/about/contact/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['Sandown Park',
  'venue_latitude',
  51.37705,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Sandown Park',
  'venue_longitude',
  -0.36355,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Sandown Park',
  'venue_reference_elevation_m',
  18,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Sandown Park',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Main Turf Course (conservative descriptive row)**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'derived_from_verified_structure',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'Flat; hurdle; chase; NH Flat',
  'right-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Main Turf Course (conservative descriptive row)** — turf

# %% [markdown]
# ## Handedness
#
# - **Main Turf Course (conservative descriptive row)** — right-handed

# %% [markdown]
# ## Racing use
#
# - **Main Turf Course (conservative descriptive row)** — Flat; hurdle; chase; NH Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'oval plus five-furlong crossing route',
  '5f route and obstacle alignments are not separately promoted',
  'about 13f (Flat oval)',
  'straight about half a mile',
  'gradual climb',
  'Railway fences; Pond Fence',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types.',
  'derived_from_verified_structure']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Sandown` → **Sandown Park** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0474',
  'Great Britain',
  'Sandown Park',
  None,
  'racecourse_identity',
  'Sandown Park Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0475',
  'Great Britain',
  'Sandown Park',
  None,
  'study03_source_labels',
  'Sandown',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0476',
  'Great Britain',
  'Sandown Park',
  None,
  'aliases',
  'Sandown; Sandown Park',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0477',
  'Great Britain',
  'Sandown Park',
  None,
  'physical_venue_address',
  'Sandown Park Racecourse, Portsmouth Road, Esher, Surrey, KT10 9AJ',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Sandown Park Contact',
  'https://www.thejockeyclub.co.uk/sandown/about/contact/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['P0478',
  'Great Britain',
  'Sandown Park',
  None,
  'locality',
  'Esher',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0479',
  'Great Britain',
  'Sandown Park',
  None,
  'county_or_region',
  'Surrey',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0480',
  'Great Britain',
  'Sandown Park',
  None,
  'postcode',
  'KT10 9AJ',
  '2015-01-01',
  '2026-05-27',
  'The Jockey Club',
  'Sandown Park Contact',
  'https://www.thejockeyclub.co.uk/sandown/about/contact/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['P0481',
  'Great Britain',
  'Sandown Park',
  None,
  'venue_latitude',
  51.37705,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0482',
  'Great Britain',
  'Sandown Park',
  None,
  'venue_longitude',
  -0.36355,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0483',
  'Great Britain',
  'Sandown Park',
  None,
  'venue_reference_elevation_m',
  18,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102996',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0484',
  'Great Britain',
  'Sandown Park',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P0946',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'course_or_track_name',
  'Main Turf Course (conservative descriptive row)',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0947',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0948',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0949',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'racing_use',
  'Flat; hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0950',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0951',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'course_geometry',
  'oval plus five-furlong crossing route',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0952',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'physical_relationship',
  '5f route and obstacle alignments are not separately promoted',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0953',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'circumference_or_length',
  'about 13f (Flat oval)',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0954',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'straight_length_or_route',
  'straight about half a mile',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0955',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'gradients_or_elevation_characteristics',
  'gradual climb',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure'],
 ['P0956',
  'Great Britain',
  'Sandown Park',
  'Main Turf Course (conservative descriptive row)',
  'permanent_obstacles_or_distinctive_features',
  'Railway fences; Pond Fence',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'The governed row name is analytical/descriptive unless the source explicitly names it; it does not manufacture additional tracks from '
  'race types. Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not '
  'automatically interpreted as a separate permanent track.',
  'derived_from_verified_structure']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [['Sandown Park',
  'Hurdle Course / Chase Course',
  'secondary course-guide wording',
  'possible obstacle alignments',
  'Guide wording distinguishes disciplines/features, but this pass lacks adequate physical evidence that they are separately recognised '
  'permanent courses rather than alignments on one turf complex.',
  'Racing TV',
  'Sandown Park Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/sandown-park',
  '2026-08-11',
  'candidate_requires_authoritative_confirmation']],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Sandown Park',
  'BHA Heritage gives K10 9AJ; Jockey Club contact material gives KT10 9AJ.',
  'BHA Heritage versus Jockey Club',
  'Typographic postcode error.',
  'Use official KT10 9AJ.',
  'medium']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Sandown Park Racecourse is represented by 1 governed physical course/track/configuration row(s) in this research model: Main Turf Course (conservative descriptive row). One broad turf complex governed conservatively; candidate hurdle/chase alignments remain unpromoted. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Sandown Park'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Sandown Park' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
