# %% [markdown]
# # Exeter
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Exeter**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Exeter`
# - Research-dossier venue label: `Exeter Racecourse`
# - Physical-model confidence: **high**
# - Key temporal boundary: No material in-scope physical-model boundary established in this pass.

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Exeter`
#
# Exeter Racecourse is represented by 2 governed physical course/track/configuration row(s) in this research model: Chase Course; Hurdle Course. Secondary technical evidence explicitly places the chase course outside the hurdle course. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Exeter', 'Exeter']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Exeter',
  'Exeter Racecourse, Kenn, Exeter, Devon, EX6 7XS',
  'Kenn / Exeter',
  'Devon',
  'EX6 7XS',
  50.64109,
  -3.55811,
  233,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Exeter',
  'racecourse_identity',
  'Exeter Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Exeter',
  'study03_source_labels',
  'Exeter',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Exeter',
  'aliases',
  'Exeter',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Exeter',
  'physical_venue_address',
  'Exeter Racecourse, Kenn, Exeter, Devon, EX6 7XS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['Exeter',
  'locality',
  'Kenn / Exeter',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Exeter',
  'county_or_region',
  'Devon',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Exeter',
  'postcode',
  'EX6 7XS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['Exeter',
  'venue_latitude',
  50.64109,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Exeter',
  'venue_longitude',
  -3.55811,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Exeter',
  'venue_reference_elevation_m',
  233,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Exeter',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **Chase Course; Hurdle Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Exeter', 'Chase Course', 'verified_secondary_technical', 'course/track', '2015-01-01', '2026-05-27', 'turf', 'chase', 'right-handed'],
 ['Exeter',
  'Hurdle Course',
  'verified_secondary_technical',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; NH Flat',
  'right-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **Chase Course** — turf
# - **Hurdle Course** — turf

# %% [markdown]
# ## Handedness
#
# - **Chase Course** — right-handed
# - **Hurdle Course** — right-handed

# %% [markdown]
# ## Racing use
#
# - **Chase Course** — chase
# - **Hurdle Course** — hurdle; NH Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Exeter',
  'Chase Course',
  'outer National Hunt alignment',
  'outside the hurdle course',
  'venue circuit about 2 miles',
  None,
  'hilly; long climbs',
  None,
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  None,
  'verified_secondary_technical'],
 ['Exeter',
  'Hurdle Course',
  'inner National Hunt alignment',
  'inside chase course',
  'venue circuit about 2 miles',
  None,
  'hilly; long climbs',
  None,
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  None,
  'verified_secondary_technical']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Exeter` → **Exeter** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0166',
  'Great Britain',
  'Exeter',
  None,
  'racecourse_identity',
  'Exeter Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0167',
  'Great Britain',
  'Exeter',
  None,
  'study03_source_labels',
  'Exeter',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0168',
  'Great Britain',
  'Exeter',
  None,
  'aliases',
  'Exeter',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0169',
  'Great Britain',
  'Exeter',
  None,
  'physical_venue_address',
  'Exeter Racecourse, Kenn, Exeter, Devon, EX6 7XS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'derived_from_verified_location'],
 ['P0170',
  'Great Britain',
  'Exeter',
  None,
  'locality',
  'Kenn / Exeter',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0171',
  'Great Britain',
  'Exeter',
  None,
  'county_or_region',
  'Devon',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0172',
  'Great Britain',
  'Exeter',
  None,
  'postcode',
  'EX6 7XS',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'derived_from_verified_location'],
 ['P0173',
  'Great Britain',
  'Exeter',
  None,
  'venue_latitude',
  50.64109,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0174',
  'Great Britain',
  'Exeter',
  None,
  'venue_longitude',
  -3.55811,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0175',
  'Great Britain',
  'Exeter',
  None,
  'venue_reference_elevation_m',
  233,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29102972',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0176',
  'Great Britain',
  'Exeter',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1097',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'course_or_track_name',
  'Chase Course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1098',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1099',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1100',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'racing_use',
  'chase',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1101',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1102',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'course_geometry',
  'outer National Hunt alignment',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1103',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'physical_relationship',
  'outside the hurdle course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1104',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'circumference_or_length',
  'venue circuit about 2 miles',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1105',
  'Great Britain',
  'Exeter',
  'Chase Course',
  'gradients_or_elevation_characteristics',
  'hilly; long climbs',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1106',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'course_or_track_name',
  'Hurdle Course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1107',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1108',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1109',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'racing_use',
  'hurdle; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1110',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'handedness',
  'right-handed',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1111',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'course_geometry',
  'inner National Hunt alignment',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1112',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'physical_relationship',
  'inside chase course',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1113',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'circumference_or_length',
  'venue circuit about 2 miles',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical'],
 ['P1114',
  'Great Britain',
  'Exeter',
  'Hurdle Course',
  'gradients_or_elevation_characteristics',
  'hilly; long climbs',
  '2015-01-01',
  '2026-05-27',
  'Racing TV',
  'Exeter Racecourse Guide',
  'https://www.racingtv.com/racecourses/uk/exeter',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_secondary_technical']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Exeter Racecourse is represented by 2 governed physical course/track/configuration row(s) in this research model: Chase Course; Hurdle Course. Secondary technical evidence explicitly places the chase course outside the hurdle course. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Exeter'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Exeter' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
