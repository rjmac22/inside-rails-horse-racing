# %% [markdown]
# # Southwell
#
# Racecourse evidence notebook supporting Study 03: **British racecourse and course identity**.
#
# This notebook is self-contained: the governed venue/course records and their provenance are written directly into the notebook.

# %% [markdown]
# ## Scope
#
# - Racecourse: **Southwell**
# - Jurisdiction: **Great Britain**
# - Study period: **2015-01-01 to 2026-05-27**
# - Study 03 source label(s): `Southwell`, `Southwell (AW)`
# - Research-dossier venue label: `Southwell Racecourse`
# - Physical-model confidence: **high**
# - Key temporal boundary: All-Weather Flat Track — Fibresand: 2015-01-01 → 2021-08-15; All-Weather Flat Track — Tapeta: 2021-12-07 → 2026-05-27

# %% [markdown]
# ## Racecourse identity
#
# **Governed racecourse identity:** `Southwell`
#
# Southwell Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: All-Weather Flat Track — Fibresand; All-Weather Flat Track — Tapeta; Turf Jumps Course. Official operator material proves adjacent all-weather Flat and turf Jumps courses; Fibresand changed to Tapeta in 2021. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# Evidence, Inside Rails derivation, candidates and unresolved questions are kept separate.

# %% [markdown]
# ## Source-data labels
#
# The following source label(s) map to this governed racecourse identity. A source label is not automatically a complete course/track inventory.

# %%
import pandas as pd

# %%
source_label_mapping = pd.DataFrame(
    [['Great Britain', 'Southwell', 'Southwell'], ['Great Britain', 'Southwell (AW)', 'Southwell']],
    columns=['jurisdiction', 'candidate_course_label', 'racecourse_identity'],
)
source_label_mapping

# %% [markdown]
# ## Location metadata
#
# Location is a **venue-level** property. Coordinates and elevation are retained only at the precision supported by the cited sources; they are not represented as surveyed course-centre coordinates or a course elevation profile.

# %%
location_metadata = pd.DataFrame(
    [['Southwell',
  'Southwell Racecourse, Occupation Lane, Rolleston, Nottinghamshire, NG25 0FT',
  'Rolleston / Southwell',
  'Nottinghamshire',
  'NG25 0FT',
  53.06892,
  -0.90845,
  16,
  'Europe/London',
  'secondary_geospatial_reference',
  'single venue reference elevation; NOT course profile']],
    columns=['racecourse_identity',
 'address',
 'locality',
 'county_or_region',
 'postcode',
 'latitude',
 'longitude',
 'elevation_m',
 'iana_timezone',
 'coordinate_status',
 'elevation_status'],
)
location_metadata

# %% [markdown]
# ### Location provenance

# %%
location_provenance = pd.DataFrame(
    [['Southwell',
  'racecourse_identity',
  'Southwell Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity.',
  'verified_official'],
 ['Southwell',
  'study03_source_labels',
  'Southwell; Southwell (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['Southwell',
  'aliases',
  'Southwell',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['Southwell',
  'physical_venue_address',
  'Southwell Racecourse, Occupation Lane, Rolleston, Nottinghamshire, NG25 0FT',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Owners & Trainers — Racecourse Address',
  'https://www.southwell-racecourse.co.uk/owners-and-trainers',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['Southwell',
  'locality',
  'Rolleston / Southwell',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['Southwell',
  'county_or_region',
  'Nottinghamshire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['Southwell',
  'postcode',
  'NG25 0FT',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Owners & Trainers — Racecourse Address',
  'https://www.southwell-racecourse.co.uk/owners-and-trainers',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['Southwell',
  'venue_latitude',
  53.06892,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Southwell',
  'venue_longitude',
  -0.90845,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['Southwell',
  'venue_reference_elevation_m',
  16,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['Southwell',
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location']],
    columns=['racecourse_identity',
 'field',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
location_provenance

# %% [markdown]
# ## Recognised courses and tracks
#
# Governed study-period inventory: **All-Weather Flat Track — Fibresand; All-Weather Flat Track — Tapeta; Turf Jumps Course**.
#
# Named starts, temporary rail positions, race-type headings and uncertain candidates are not silently promoted to permanent course identities.

# %%
course_inventory = pd.DataFrame(
    [['Southwell',
  'All-Weather Flat Track — Fibresand',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2021-08-15',
  'Fibresand',
  'Flat; AW',
  'left-handed'],
 ['Southwell',
  'All-Weather Flat Track — Tapeta',
  'verified_official',
  'course/track',
  '2021-12-07',
  '2026-05-27',
  'Tapeta',
  'Flat; AW',
  'left-handed'],
 ['Southwell',
  'Turf Jumps Course',
  'verified_official',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'turf',
  'hurdle; chase; NH Flat',
  'left-handed']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'identity_status',
 'entity_type',
 'valid_from',
 'valid_to',
 'surface',
 'primary_use',
 'handedness'],
)
course_inventory

# %% [markdown]
# ## Surface
#
# - **All-Weather Flat Track — Fibresand** — Fibresand
# - **All-Weather Flat Track — Tapeta** — Tapeta
# - **Turf Jumps Course** — turf

# %% [markdown]
# ## Handedness
#
# - **All-Weather Flat Track — Fibresand** — left-handed
# - **All-Weather Flat Track — Tapeta** — left-handed
# - **Turf Jumps Course** — left-handed

# %% [markdown]
# ## Racing use
#
# - **All-Weather Flat Track — Fibresand** — Flat; AW
# - **All-Weather Flat Track — Tapeta** — Flat; AW
# - **Turf Jumps Course** — hurdle; chase; NH Flat

# %% [markdown]
# ## Course layout and physical characteristics
#
# Course-specific geometry, relationships, lengths, gradients and distinctive features are included only where the research supports them.

# %%
course_physical_characteristics = pd.DataFrame(
    [['Southwell',
  'All-Weather Flat Track — Fibresand',
  'all-weather Flat track',
  'adjacent to the separate Jumps course',
  None,
  None,
  None,
  None,
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing.',
  'verified_official'],
 ['Southwell',
  'All-Weather Flat Track — Tapeta',
  'all-weather Flat track',
  'adjacent to the separate Jumps course',
  None,
  None,
  None,
  None,
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  None,
  'verified_official'],
 ['Southwell',
  'Turf Jumps Course',
  'separate Jumps course',
  'adjacent to the all-weather Flat course',
  None,
  None,
  None,
  None,
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  None,
  'verified_official']],
    columns=['racecourse_identity',
 'course_or_track_name',
 'course_geometry',
 'physical_relationship',
 'circumference_or_length',
 'straight_length_or_route',
 'gradients_or_elevation_characteristics',
 'permanent_obstacles_or_distinctive_features',
 'source_authority',
 'source_title',
 'exact_source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_physical_characteristics

# %% [markdown]
# ## Historical changes
#
# Historical layouts, surfaces and racing-use changes are date-bounded where the evidence allows. Older physical models are not projected across redevelopment or resurfacing boundaries.

# %%
historical_changes = pd.DataFrame(
    [['Southwell',
  '2021-08 to 2021-12',
  'resurfacing',
  'All-Weather Flat Track',
  'Fibresand',
  'Tapeta',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  'verified_official',
  'Major surface boundary: final announced Fibresand fixture 15 Aug 2021; first Tapeta racing 7 Dec 2021.'],
 ['Southwell',
  '2023 flood; refurbishment in 2024',
  'surface refurbishment',
  'Tapeta All-Weather Track',
  'Tapeta affected by severe flooding',
  'Tapeta refurbished',
  'Southwell Racecourse / Arena Racing Company',
  'All Weather Championships',
  'https://www.southwell-racecourse.co.uk/racing-highlights/all-weather-championships',
  '2026-08-11',
  'verified_official',
  'In-scope physical maintenance relevant to future surface-condition modelling.']],
    columns=['racecourse_identity',
 'change_date_or_period',
 'change_type',
 'affected_course_or_track',
 'before_state',
 'after_state',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status',
 'model_impact'],
)
historical_changes

# %% [markdown]
# ## Source mapping
#
# `Southwell`, `Southwell (AW)` → **Southwell** → governed constituent course/track inventory above.
#
# This preserves the Study 03 rule: `source label != racecourse != course/track`.

# %% [markdown]
# ## Evidence and provenance
#
# Each material assertion retains its source authority, source title, exact URL, temporal validity, evidence note and verification status. A course-identity citation is not automatically treated as proof of every characteristic.

# %%
course_characteristic_provenance = pd.DataFrame(
    [['P0496',
  'Great Britain',
  'Southwell',
  None,
  'racecourse_identity',
  'Southwell Racecourse',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Stable venue identity. For Newmarket the master parent is an analytical grouping over the two officially named racecourses; see track '
  'rows.',
  'verified_official'],
 ['P0497',
  'Great Britain',
  'Southwell',
  None,
  'study03_source_labels',
  'Southwell; Southwell (AW)',
  '2015-01-01',
  '2026-05-27',
  'Inside Rails',
  'Study 03 — What is a British racecourse?',
  'https://github.com/rjmac22/inside-rails-horse-racing/blob/audit/retrospective-implementation-closeout/studies/jurisdictions/great_britain/03_british_racecourse_and_course_identity.ipynb',
  '2026-08-11',
  'Source labels from the governed study inventory; source labels are not assumed to equal venue or physical track identities.',
  'verified'],
 ['P0498',
  'Great Britain',
  'Southwell',
  None,
  'aliases',
  'Southwell',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'Aliases/common labels are retained only as identity aids and do not create separate physical venues.',
  'derived_from_verified_structure'],
 ['P0499',
  'Great Britain',
  'Southwell',
  None,
  'physical_venue_address',
  'Southwell Racecourse, Occupation Lane, Rolleston, Nottinghamshire, NG25 0FT',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Owners & Trainers — Racecourse Address',
  'https://www.southwell-racecourse.co.uk/owners-and-trainers',
  '2026-08-11',
  'Best-supported venue address/locality/postcode formulation. Where the source lacks a street element, no street is invented.',
  'verified_official'],
 ['P0500',
  'Great Britain',
  'Southwell',
  None,
  'locality',
  'Rolleston / Southwell',
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary spatial reference used to localise the venue; not a legal address determination.',
  'secondary_geospatial_reference'],
 ['P0501',
  'Great Britain',
  'Southwell',
  None,
  'county_or_region',
  'Nottinghamshire',
  '2015-01-01',
  '2026-05-27',
  'British Horseracing Authority',
  'Heritage — British racecourses',
  'https://www.britishhorseracing.com/heritage/',
  '2026-08-11',
  'County/region normalised where historic/current administrative labels differ. Known BHA Heritage errors are retained in Human Review.',
  'verified_official'],
 ['P0502',
  'Great Britain',
  'Southwell',
  None,
  'postcode',
  'NG25 0FT',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Owners & Trainers — Racecourse Address',
  'https://www.southwell-racecourse.co.uk/owners-and-trainers',
  '2026-08-11',
  'Current best-supported postcode. Conflicting BHA Heritage values are recorded separately rather than silently discarded.',
  'verified_official'],
 ['P0503',
  'Great Britain',
  'Southwell',
  None,
  'venue_latitude',
  53.06892,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0504',
  'Great Britain',
  'Southwell',
  None,
  'venue_longitude',
  -0.90845,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Secondary geospatial venue reference point; NOT an official/surveyed rail, course centroid or start coordinate.',
  'secondary_geospatial_reference'],
 ['P0505',
  'Great Britain',
  'Southwell',
  None,
  'venue_reference_elevation_m',
  16,
  '2015-01-01',
  '2026-05-27',
  'Mapcarta / underlying OpenStreetMap-GeoNames-Wikidata',
  'Racecourse map',
  'https://mapcarta.com/29103044',
  '2026-08-11',
  'Single reference elevation at/near the mapped venue point. It is not course minimum/maximum/elevation profile.',
  'secondary_geospatial_reference'],
 ['P0506',
  'Great Britain',
  'Southwell',
  None,
  'iana_timezone',
  'Europe/London',
  '2015-01-01',
  '2026-05-27',
  'IANA Time Zone Database',
  'zone1970.tab',
  'https://data.iana.org/time-zones/tzdb/zone1970.tab',
  '2026-08-11',
  'Derived from the verified Great Britain venue location; IANA maps GB to Europe/London.',
  'derived_from_verified_location'],
 ['P1291',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'course_or_track_name',
  'All-Weather Flat Track — Fibresand',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1292',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1293',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'surface',
  'Fibresand',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1294',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'racing_use',
  'Flat; AW',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1295',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1296',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'course_geometry',
  'all-weather Flat track',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1297',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Fibresand',
  'physical_relationship',
  'adjacent to the separate Jumps course',
  '2015-01-01',
  '2021-08-15',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell Receives Planning Permission For Resurfacing',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-receives-planning-permission-for-resurfacing',
  '2026-08-11',
  '15 August 2021 was announced as the final Fibresand fixture before resurfacing. Assertion retained at the narrowest physical level '
  'supported. A source using a race-type/course heading is not automatically interpreted as a separate permanent track.',
  'verified_official'],
 ['P1298',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'course_or_track_name',
  'All-Weather Flat Track — Tapeta',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1299',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'entity_type',
  'course/track',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1300',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'surface',
  'Tapeta',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1301',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'racing_use',
  'Flat; AW',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1302',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'handedness',
  'left-handed',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1303',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'course_geometry',
  'all-weather Flat track',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1304',
  'Great Britain',
  'Southwell',
  'All-Weather Flat Track — Tapeta',
  'physical_relationship',
  'adjacent to the separate Jumps course',
  '2021-12-07',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'Southwell’s Tapeta Track Celebrates First Anniversary',
  'https://www.southwell-racecourse.co.uk/news/racing/southwell-s-tapeta-track-celebrates-first-anniversary',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1305',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'course_or_track_name',
  'Turf Jumps Course',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1306',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'entity_type',
  'course/track',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1307',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'surface',
  'turf',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1308',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'racing_use',
  'hurdle; chase; NH Flat',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1309',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'handedness',
  'left-handed',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1310',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'course_geometry',
  'separate Jumps course',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official'],
 ['P1311',
  'Great Britain',
  'Southwell',
  'Turf Jumps Course',
  'physical_relationship',
  'adjacent to the all-weather Flat course',
  '2015-01-01',
  '2026-05-27',
  'Southwell Racecourse / Arena Racing Company',
  'BHA Confirms Six Fixture Alterations',
  'https://www.southwell-racecourse.co.uk/news/racing/bha-confirms-six-fixture-alterations',
  '2026-08-11',
  'Assertion retained at the narrowest physical level supported. A source using a race-type/course heading is not automatically '
  'interpreted as a separate permanent track.',
  'verified_official']],
    columns=['assertion_id',
 'jurisdiction',
 'racecourse_identity',
 'course_or_track_name',
 'characteristic',
 'value',
 'valid_from',
 'valid_to',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'evidence_note',
 'verification_status'],
)
course_characteristic_provenance

# %% [markdown]
# ## Candidates not promoted
#
# Named routes/components that do not meet the current governance threshold remain below the governed inventory.

# %%
course_candidates_not_promoted = pd.DataFrame(
    [],
    columns=['racecourse_identity',
 'candidate_entity',
 'source_context',
 'classified_as',
 'reason_not_promoted',
 'source_authority',
 'source_title',
 'source_url',
 'accessed_date',
 'verification_status'],
)
course_candidates_not_promoted

# %% [markdown]
# ## Human-review items
#
# Contradictory or potentially misleading source material is retained for explicit review rather than silently normalised.

# %%
human_review_items = pd.DataFrame(
    [['Southwell',
  'Current official operator address uses NG25 0FT while BHA Heritage lists NG25 0TS.',
  'Southwell official site versus BHA Heritage',
  'Postal/location provenance conflict.',
  'Use current official NG25 0FT and retain the BHA value as an audit anomaly.',
  'medium']],
    columns=['racecourse_identity', 'anomaly', 'conflicting_sources_or_terms', 'why_human_review', 'conservative_handling', 'priority'],
)
human_review_items

# %% [markdown]
# ## Unresolved questions
#
# Unknowns remain unresolved rather than being filled from general racing knowledge.

# %%
unresolved_questions = pd.DataFrame(
    [],
    columns=['racecourse_identity', 'question', 'why_unresolved', 'research_attempted', 'impact', 'unresolved_class', 'verification_status'],
)
unresolved_questions

# %% [markdown]
# ## Conclusion
#
# Southwell Racecourse is represented by 3 governed physical course/track/configuration row(s) in this research model: All-Weather Flat Track — Fibresand; All-Weather Flat Track — Tapeta; Turf Jumps Course. Official operator material proves adjacent all-weather Flat and turf Jumps courses; Fibresand changed to Tapeta in 2021. Course names labelled 'descriptive' are analytical identifiers, not claims of an official name. Temporary rails/dolling, start positions and race-type headings are not promoted.
#
# The notebook records the strongest supported physical model without converting race-type terminology or uncertain candidates into unsupported course identities.

# %%
assert len(source_label_mapping) >= 1
assert len(location_metadata) == 1
assert location_metadata.iloc[0]['racecourse_identity'] == 'Southwell'
assert location_metadata.iloc[0]['iana_timezone'] == 'Europe/London'
assert len(course_inventory) >= 1
if len(course_characteristic_provenance):
    assert course_characteristic_provenance['source_url'].fillna('').str.len().gt(0).all()
print('Southwell' + ' venue, course model and provenance checks passed.')

# %% [markdown]
# ## Findings from later studies
#
# _None yet._
